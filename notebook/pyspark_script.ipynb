# %% [markdown]
# # Script transfer learning et réduction de dimension

# %%
print("Welcome to my EMR Notebook!")

# %%
# %%info

# %%
spark

# %%
import pandas as pd
import numpy as np
import io
import os
import tensorflow as tf
from PIL import Image
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras import Model
from pyspark.sql.functions import col, pandas_udf, PandasUDFType, element_at, split
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# # Configuration des paths

# %%
# Images + Output + Outpu PCA + Output CSV: 

PATH = 's3://projetfruits'
PATH_Data = PATH+'/data/input/Test'
PATH_Data_sample = PATH+'/data/input/sample'
PATH_Result = PATH+'/data/output'
PATH_Result_pca = PATH+'/data/output_pca'
PATH_Result_csv = PATH+'/data/output_csv'

# Output sample 
PATH_Result_sample = PATH+'/data_sample/output'
PATH_Result_pca_sample = PATH+'/data_sample/output_pca'
PATH_Result_csv_sample = PATH+'/data_sample/output_csv'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
print('PATH:        '+ PATH + '\nPATH_Data:   '+ PATH_Data + '\nPATH_Result: '+ PATH_Result + '\nPATH_Result_pca: ' + PATH_Result_pca + '\nPATH_Result_CSV: ' + PATH_Result_csv)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# PATH:        s3://projetfruits
# PATH_Data:   s3://projetfruits/data/input/Test
# PATH_Result: s3://projetfruits/data/output
# PATH_Result_pca: s3://projetfruits/data/output_pca

# %% [markdown]
# # Importation des images

# %% [markdown]
# Les images sont situées dans un bucket S3, en suivant le chemin : `s3://projetfruits/data/input/Test`

# %%
# images_sample = spark.read.format("binaryFile") \
#   .option("pathGlobFilter", "*.jpg") \
#   .option("recursiveFileLookup", "true") \
#   .load(PATH_Data_sample)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# images_sample.show(5)

# %%
# Pour comparer à l'exécution en local :
images = spark.read.format("binaryFile") \
  .option("pathGlobFilter", "*.jpg") \
  .option("recursiveFileLookup", "true") \
  .load(PATH_Data)

# %% [markdown]
# <u>Affichage des 5 premières images contenant</u> :
#  - le path de l'image
#  - la date et heure de sa dernière modification
#  - sa longueur
#  - son contenu encodé en valeur hexadécimal

# %%
images.show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+-------------------+------+--------------------+
# |                path|   modificationTime|length|             content|
# +--------------------+-------------------+------+--------------------+
# |s3://projetfruits...|2023-06-18 09:35:06|125135|[FF D8 FF E0 00 1...|
# |s3://projetfruits...|2023-06-18 09:35:06|124785|[FF D8 FF E0 00 1...|
# |s3://projetfruits...|2023-06-18 09:35:04|123514|[FF D8 FF E0 00 1...|
# |s3://projetfruits...|2023-06-18 09:35:08|122958|[FF D8 FF E0 00 1...|
# |s3://projetfruits...|2023-06-18 09:35:05|122807|[FF D8 FF E0 00 1...|
# +--------------------+-------------------+------+--------------------+
# only showing top 5 rows

# %% [markdown]
# On conserve le chemin d'accès à l'image, et nous ajoutons une colonne labels de chaque image:

# %% [markdown]
# `withColumn()`: est une fonction de transformation de DataFrame qui est utilisée pour modifier la valeur, convertir le type de données d'une colonne existante, créer une nouvelle colonne, etc.

# %%
images = images.withColumn('label', element_at(split(images['path'], '/'),-2))
print(images.printSchema())
print(images.select('path','label').show(5,False))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- path: string (nullable = true)
#  |-- modificationTime: timestamp (nullable = true)
#  |-- length: long (nullable = true)
#  |-- content: binary (nullable = true)
#  |-- label: string (nullable = true)
#
# None
# +--------------------------------------------------------+-----------+
# |path                                                    |label      |
# +--------------------------------------------------------+-----------+
# |s3://projetfruits/data/input/Test/apple_hit_1/r0_115.jpg|apple_hit_1|
# |s3://projetfruits/data/input/Test/apple_hit_1/r0_119.jpg|apple_hit_1|
# |s3://projetfruits/data/input/Test/apple_hit_1/r0_107.jpg|apple_hit_1|
# |s3://projetfruits/data/input/Test/apple_hit_1/r0_143.jpg|apple_hit_1|
# |s3://projetfruits/data/input/Test/apple_hit_1/r0_111.jpg|apple_hit_1|
# +--------------------------------------------------------+-----------+
# only showing top 5 rows
#
# None

# %%
# images_sample = images_sample.withColumn('label', element_at(split(images_sample['path'], '/'),-2))
# print(images_sample.printSchema())
# print(images_sample.select('path','label').show(5,False))

# %% [markdown]
# # MobileNetV2

# %%
model = MobileNetV2(weights='imagenet',
                    include_top=True,
                    input_shape=(224, 224, 3))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 [==============================] - 1s 0us/step

# %%
new_model = Model(inputs=model.input, outputs=model.layers[-2].output)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# # Spark Broadcast

# %% [markdown]
# Dans Spark RDD et DataFrame, les variables de diffusion sont des variables partagées en lecture seule qui sont mises en cache et disponibles sur tous les nœuds d'un cluster afin d'accéder ou d'utiliser les tâches.
#
# Au lieu d'envoyer ces données avec chaque tâche, Spark distribue des variables de diffusion à la machine en utilisant des algorithmes de diffusion efficaces pour réduire les coûts de communication.
#
# Au lieu de distribuer ces informations avec chaque tâche sur le réseau (surcharge et perte de temps), nous pouvons utiliser la variable de diffusion pour mettre en cache ces informations de recherche sur chaque machine et les tâches utilisent ces informations mises en cache lors de l'exécution des transformations.

# %% [markdown]
# ## Comment fonctionne Spark Broadcast ?

# %% [markdown]
# Les variables de diffusion sont utilisées de la même manière pour RDD, DataFrame et Dataset. Lorsque vous exécutez un RDD Spark, des jobs DataFrame dont les variables de diffusion sont définies et utilisées, Spark effectue les opérations suivantes:
#
# Spark breaks the job into stages that have distributed shuffling and actions are executed with in the stage.
# Later Stages are also broken into tasks
# Spark broadcasts the common data (reusable) needed by tasks within each stage.
# The broadcasted data is cache in serialized format and deserialized before executing each task.

# %%
brodcast_weights = sc.broadcast(new_model.get_weights())
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
new_model.summary()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
def model_fn():
    """
    Returns a MobileNetV2 model with top layer removed 
    and broadcasted pretrained weights.
    """
    model = MobileNetV2(weights='imagenet',
                        include_top=True,
                        input_shape=(224, 224, 3))
    for layer in model.layers:
        layer.trainable = False
    new_model = Model(inputs=model.input,
                  outputs=model.layers[-2].output)
    new_model.set_weights(brodcast_weights.value)
    return new_model
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
def preprocess(content):
    """
    Preprocesses raw image bytes for prediction.
    """
    img = Image.open(io.BytesIO(content)).resize([224, 224])
    arr = img_to_array(img)
    return preprocess_input(arr)

def featurize_series(model, content_series):
    """
    Featurize a pd.Series of raw images using the input model.
    :return: a pd.Series of image features
    """
    input = np.stack(content_series.map(preprocess))
    preds = model.predict(input)
    # For some layers, output features will be multi-dimensional tensors.
    # We flatten the feature tensors to vectors for easier storage in Spark DataFrames.
    output = [p.flatten() for p in preds]
    return pd.Series(output)

@pandas_udf('array<float>', PandasUDFType.SCALAR_ITER)
def featurize_udf(content_series_iter):
    '''
    This method is a Scalar Iterator pandas UDF wrapping our featurization function.
    The decorator specifies that this returns a Spark DataFrame column of type ArrayType(FloatType).

    :param content_series_iter: This argument is an iterator over batches of data, where each batch
                              is a pandas Series of image data.
    '''
    # With Scalar Iterator pandas UDFs, we can load the model once and then re-use it
    # for multiple data batches.  This amortizes the overhead of loading big models.
    model = model_fn()
    for content_series in content_series_iter:
        yield featurize_series(model, content_series)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# /mnt1/yarn/usercache/livy/appcache/application_1687080233630_0001/container_1687080233630_0001_01_000001/pyspark.zip/pyspark/sql/pandas/functions.py:398: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.

# %%
print(PATH_Result)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# s3://projetfruits/data/output

# %%
features_df = images.repartition(24).select(col("path"),
                                            col("label"),
                                            featurize_udf("content").alias("features")
                                           )
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# features_df_sample = images_sample.repartition(24).select(col("path"),
#                                             col("label"),
#                                             featurize_udf("content").alias("features")
#                                            )

# %%
# features_df_sample.write.mode("overwrite").parquet(PATH_Result_sample)

# %%
features_df.write.mode("overwrite").parquet(PATH_Result)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df = pd.read_parquet(PATH_Result, engine='pyarrow')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df.head()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#                                                 path  ...                                           features
# 0  s3://projetfruits/data/input/Test/apple_hit_1/...  ...  [0.21089473, 0.08602117, 1.3680781, 0.0, 0.353...
# 1  s3://projetfruits/data/input/Test/apple_hit_1/...  ...  [0.00890907, 0.20073263, 2.0521815, 0.0, 0.176...
# 2  s3://projetfruits/data/input/Test/apple_hit_1/...  ...  [0.21464187, 0.24185033, 0.29451635, 0.0, 0.0,...
# 3  s3://projetfruits/data/input/Test/apple_hit_1/...  ...  [0.0, 0.4196838, 0.25495315, 0.0, 0.3626423, 0...
# 4  s3://projetfruits/data/input/Test/cabbage_whit...  ...  [0.0, 0.5918541, 1.0169322, 0.0030952473, 1.66...
#
# [5 rows x 3 columns]

# %%
df.loc[0,'features'].shape
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# (1280,)

# %%
df.shape
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# (3110, 3)

# %% [markdown]
# # ResNet50

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
model_resnet = ResNet50(include_top=False)
model_resnet.summary()

# %%
bc_model_weights = sc.broadcast(model.get_weights())
def model_fn():
    model_resnet = ResNet50(weights=None, include_top=False)
    model_resnet.set_weights(bc_model_weights.value)
    return model

# %%
features_df_resnet = images.repartition(16).select(col("path"), featurize_udf("content").alias("features"))

# %% [markdown]
# # ACP

# %%
from pyspark.sql.functions import col, pandas_udf, PandasUDFType, element_at, split
from pyspark.ml.functions import array_to_vector, vector_to_array
from pyspark.ml.feature import PCA
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_for_pca = spark.read.parquet(PATH_Result)
df_for_pca.show(6)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+-----------+--------------------+
# |                path|      label|            features|
# +--------------------+-----------+--------------------+
# |s3://projetfruits...|apple_hit_1|[0.263347, 0.1623...|
# |s3://projetfruits...|apple_hit_1|[0.58557224, 1.87...|
# |s3://projetfruits...|apple_hit_1|[0.26966664, 0.97...|
# |s3://projetfruits...|apple_hit_1|[1.0179651, 0.093...|
# |s3://projetfruits...|apple_hit_1|[0.5515656, 0.021...|
# |s3://projetfruits...|apple_hit_1|[0.34845087, 0.02...|
# +--------------------+-----------+--------------------+
# only showing top 6 rows

# %%
# conversion du type de la colonne 'features' en vecteur pyspark
df_for_pca = df_for_pca.withColumn('features', array_to_vector('features'))
df.show(6)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
scaler = StandardScaler(
    inputCol = 'features', 
    outputCol = 'scaledFeatures',
    withMean = True,
    withStd = True
).fit(df_for_pca)

# when we transform the dataframe, the old
# feature will still remain in it
df_scaled = scaler.transform(df_for_pca)
df_scaled.show(6)

# %%
# PCA
pca = PCA(k=1280, inputCol="scaledFeatures", outputCol="pca_features")
model_pca = pca.fit(df_scaled)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Explained Variance Ratio [1.44961505e-01 1.15144214e-01 7.38885286e-02 5.09932777e-02
#  3.92854630e-02 3.52634933e-02 2.92427913e-02 2.65665064e-02
#  2.27421408e-02 2.14503369e-02 1.91034375e-02 1.71291278e-02
#  1.60559494e-02 1.40448307e-02 1.22771976e-02 1.11807230e-02
#  1.07439526e-02 1.00952885e-02 9.62175239e-03 9.03170276e-03
#  8.35238400e-03 7.20685676e-03 6.94363588e-03 6.80979339e-03
#  6.60176396e-03 6.26345089e-03 5.87395728e-03 5.62397441e-03
#  5.15209631e-03 5.05334855e-03 4.72562421e-03 4.50104595e-03
#  4.27514616e-03 4.09877532e-03 3.92757084e-03 3.81403976e-03
#  3.53539137e-03 3.46280770e-03 3.27054083e-03 3.20247262e-03
#  3.05860352e-03 2.91223264e-03 2.90376925e-03 2.86105559e-03
#  2.70295579e-03 2.66640834e-03 2.57354994e-03 2.51597879e-03
#  2.48221000e-03 2.37467662e-03 2.33495183e-03 2.25474774e-03
#  2.16052045e-03 2.12848518e-03 2.07046965e-03 2.03657355e-03
#  1.99707444e-03 1.95644681e-03 1.92090929e-03 1.89121152e-03
#  1.84761902e-03 1.78972728e-03 1.76778673e-03 1.75651187e-03
#  1.68300560e-03 1.65178184e-03 1.61199671e-03 1.57663315e-03
#  1.55286870e-03 1.52111550e-03 1.48186271e-03 1.47389644e-03
#  1.44538414e-03 1.42447643e-03 1.35896238e-03 1.35294784e-03
#  1.31368589e-03 1.29268643e-03 1.27086357e-03 1.24489680e-03
#  1.22991805e-03 1.21101134e-03 1.18176411e-03 1.17039797e-03
#  1.14620903e-03 1.13695678e-03 1.11491495e-03 1.10794358e-03
#  1.08713424e-03 1.07492266e-03 1.05629279e-03 1.03056188e-03
#  1.02111737e-03 1.01585079e-03 9.98761415e-04 9.90303651e-04
#  9.81889908e-04 9.52953658e-04 9.46250145e-04 9.29014916e-04
#  9.18178526e-04 9.10868825e-04 8.93624541e-04 8.79151417e-04
#  8.71633369e-04 8.47059636e-04 8.37832898e-04 8.28651449e-04
#  8.21531617e-04 8.12020678e-04 8.06405261e-04 7.83375019e-04
#  7.75600195e-04 7.66162744e-04 7.56790315e-04 7.42585189e-04
#  7.28882549e-04 7.26600827e-04 7.15623045e-04 7.00710140e-04
#  6.91301002e-04 6.87809964e-04 6.84397108e-04 6.75430628e-04
#  6.72021324e-04 6.69438392e-04 6.63405101e-04 6.46100228e-04
#  6.42181155e-04 6.28641512e-04 6.21116052e-04 6.19588968e-04
#  6.16901405e-04 6.06693481e-04 6.03852106e-04 5.93639230e-04
#  5.86396611e-04 5.76996167e-04 5.73493545e-04 5.62553419e-04
#  5.60564835e-04 5.56625917e-04 5.50993502e-04 5.47097346e-04
#  5.41793155e-04 5.34707917e-04 5.30441210e-04 5.26656015e-04
#  5.20280408e-04 5.12825552e-04 5.09918258e-04 5.08405984e-04
#  5.01303991e-04 4.95344514e-04 4.90985475e-04 4.86426105e-04
#  4.82553404e-04 4.75346714e-04 4.71723341e-04 4.63672631e-04
#  4.57792687e-04 4.54356139e-04 4.51181812e-04 4.47444918e-04
#  4.45968762e-04 4.43073914e-04 4.35189519e-04 4.28156730e-04
#  4.24105358e-04 4.23232661e-04 4.18186358e-04 4.14516889e-04
#  4.11526667e-04 4.06228681e-04 4.02807903e-04 4.01166346e-04
#  3.99480172e-04 3.94138868e-04 3.92878277e-04 3.89017919e-04
#  3.85021327e-04 3.79812999e-04 3.75563517e-04 3.74276196e-04
#  3.71640004e-04 3.67525110e-04 3.65832734e-04 3.63489023e-04
#  3.57002729e-04 3.53970664e-04 3.51331020e-04 3.48284227e-04
#  3.46628989e-04 3.41702551e-04 3.40940420e-04 3.36152847e-04
#  3.33058467e-04 3.32364690e-04 3.29678876e-04 3.27919391e-04
#  3.26864300e-04 3.25047157e-04 3.20717852e-04 3.18537363e-04
#  3.13457717e-04 3.11953445e-04 3.07072894e-04 3.05965776e-04
#  3.02910255e-04 3.01584456e-04 3.00527624e-04 2.98841454e-04
#  2.96650056e-04 2.92324105e-04 2.89872986e-04 2.86541605e-04
#  2.84672595e-04 2.82533195e-04 2.79824783e-04 2.78178834e-04
#  2.76727451e-04 2.74427585e-04 2.72352672e-04 2.70018272e-04
#  2.68000118e-04 2.67499830e-04 2.65476486e-04 2.62398046e-04
#  2.61804401e-04 2.58729328e-04 2.58068516e-04 2.54959186e-04
#  2.52994862e-04 2.50746585e-04 2.48852246e-04 2.47194208e-04
#  2.45876690e-04 2.43307736e-04 2.42754957e-04 2.41500966e-04
#  2.40293532e-04 2.38257666e-04 2.34694034e-04 2.32228990e-04
#  2.30703439e-04 2.29763908e-04 2.28375689e-04 2.27668160e-04
#  2.26013723e-04 2.24645964e-04 2.22655393e-04 2.21481176e-04
#  2.19730865e-04 2.18852091e-04 2.15870310e-04 2.12165587e-04
#  2.11659781e-04 2.10612620e-04 2.08742660e-04 2.08038625e-04
#  2.06680736e-04 2.05141455e-04 2.04393925e-04 2.02837265e-04
#  2.01667180e-04 1.99662554e-04 1.99055882e-04 1.97439561e-04
#  1.95350621e-04 1.94579193e-04 1.93974579e-04 1.92606823e-04
#  1.90316644e-04 1.88959885e-04 1.88355841e-04 1.87705477e-04
#  1.85958287e-04 1.84705845e-04 1.83160071e-04 1.82224448e-04
#  1.81380641e-04 1.80619410e-04 1.79650021e-04 1.78459801e-04
#  1.77859378e-04 1.77320292e-04 1.74952727e-04 1.73218261e-04
#  1.71815138e-04 1.71015410e-04 1.70213360e-04 1.68772114e-04
#  1.68364118e-04 1.67171510e-04 1.66328849e-04 1.65649767e-04
#  1.64250864e-04 1.63561236e-04 1.62869141e-04 1.62176738e-04
#  1.60305140e-04 1.59043757e-04 1.58498381e-04 1.57848155e-04
#  1.55902307e-04 1.55433184e-04 1.54514583e-04 1.53253692e-04
#  1.52541673e-04 1.51489861e-04 1.49855877e-04 1.49593071e-04
#  1.48683826e-04 1.47494567e-04 1.46592722e-04 1.45348518e-04
#  1.44605062e-04 1.44412909e-04 1.43874315e-04 1.43411642e-04
#  1.42088048e-04 1.41239257e-04 1.40382254e-04 1.40122500e-04
#  1.38328843e-04 1.37744320e-04 1.37405047e-04 1.36298522e-04
#  1.35937545e-04 1.35299400e-04 1.34249447e-04 1.33484672e-04
#  1.32788204e-04 1.31652923e-04 1.31342721e-04 1.31133328e-04
#  1.29863885e-04 1.28865217e-04 1.28284610e-04 1.27374224e-04
#  1.26864718e-04 1.26419142e-04 1.25920210e-04 1.24983524e-04
#  1.23797981e-04 1.23329227e-04 1.22867318e-04 1.21858798e-04
#  1.21476952e-04 1.20308167e-04]
# +--------------------+-----------+--------------------+--------------------+
# |                path|      label|            features|        pca_features|
# +--------------------+-----------+--------------------+--------------------+
# |s3://projetfruits...|apple_hit_1|[0.26334699988365...|[6.62205399600004...|
# |s3://projetfruits...|apple_hit_1|[0.58557224273681...|[7.42664254763027...|
# |s3://projetfruits...|apple_hit_1|[0.26966664195060...|[6.54201507830138...|
# |s3://projetfruits...|apple_hit_1|[1.01796507835388...|[8.13748394282309...|
# |s3://projetfruits...|apple_hit_1|[0.55156558752059...|[6.50952245440146...|
# |s3://projetfruits...|apple_hit_1|[0.34845086932182...|[5.81475542632785...|
# +--------------------+-----------+--------------------+--------------------+
# only showing top 6 rows

# %%
eigenvalues = model_pca.explainedVariance

# %%
import matplotlib.pyplot as plt
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, 'bo-')
plt.xlabel("Nombre de composantes")
plt.ylabel("Valeur propre")
plt.title("Éboulis des valeurs propres")
plt.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 0.9755732253410361

# %%
cumulative_variance = [sum(eigenvalues[:i + 1]) for i in range(len(eigenvalues))]
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, 'bo-')
plt.xlabel("Nombre de composantes")
plt.ylabel("Variance expliquée cumulée")
plt.title("Variance expliquée cumulée")
plt.show()

# %%
df_pca = model_pca.transform(df_scaled)
df_pca.show(6)

# %%
# Variance expliquée
print('Explained Variance Ratio', model_pca.explainedVariance.toArray())

# %%
# Calcul de la variance expliquée cumulée
cumulative_variance = np.cumsum(model_pca.explainedVariance.toArray())

# %%
# Trouvez l'indice où la variance expliquée cumulée atteint 99%
index = np.argmax(cumulative_variance >= 0.99)

# %%
print('Le nombre de composante retenue : ', index + 1)

# %%
# On ne garde pas la colonne 'features' et on convertit 'pca_features' en array
df_pca = df_pca.select(['path', 'label', vector_to_array('pca_features').alias('pca_features')])
df_pca.show(6)

# %%
# Enregistrement des données traitées au format "parquet" :
df_pca.repartition(20).write.mode("overwrite").parquet(PATH_Result_pca)

# %%
# not sure if this is the best way to do it
# X_pca = df_pca.rdd.map(lambda row: row.pca_features).collect()
# X_pca = np.array(X_pca)
# X_pca
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# array([[  6.622054  ,   0.35199402,  -0.8340074 , ...,   0.18379909,
#           0.17600623,  -0.17411002],
#        [  7.42664255,  -4.3644764 ,   2.71973628, ...,  -0.21253421,
#          -0.39610376,  -0.46381433],
#        [  6.54201508,   0.96564316,   1.04585803, ...,   0.51018851,
#          -0.09006563,  -0.67336332],
#        ...,
#        [  2.75335649,   6.24051248, -11.76083331, ...,   0.44407091,
#          -0.23837532,  -0.56726685],
#        [  1.04280615,   6.64341848, -12.72842514, ...,  -0.19549823,
#          -0.05322051,  -0.2028444 ],
#        [ -0.10904562,   6.45431899, -13.03566351, ...,   0.2002107 ,
#          -0.13538717,  -0.04478604]])

# %%
# Enregistrement des données traitées au format "parquet" :
df_pca.repartition(20).write.mode("overwrite").parquet(PATH_Result_pca)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Lecture des résultat pca
df__pca = pd.read_parquet(PATH_Result_pca, engine='pyarrow')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df__pca
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#                                                    path  ...                                       pca_features
# 0     s3://projetfruits/data/input/Test/apple_golden...  ...  [5.074897954419245, 7.380378554618761, -9.0521...
# 1     s3://projetfruits/data/input/Test/carrot_1/r0_...  ...  [3.290617649943695, -12.6965803492289, -2.6680...
# 2     s3://projetfruits/data/input/Test/zucchini_dar...  ...  [3.9143467931413474, -12.762743617140975, -12....
# 3     s3://projetfruits/data/input/Test/pear_1/r0_11...  ...  [4.776133265656421, 7.377103263864188, -4.0594...
# 4     s3://projetfruits/data/input/Test/eggplant_vio...  ...  [2.759077231734376, -11.002419585909834, -6.80...
# ...                                                 ...  ...                                                ...
# 3105  s3://projetfruits/data/input/Test/pear_3/r0_31...  ...  [1.8465232983500581, 5.645154383883263, -1.589...
# 3106  s3://projetfruits/data/input/Test/apple_red_3/...  ...  [-5.745054683989173, 1.8257846187282498, 0.077...
# 3107  s3://projetfruits/data/input/Test/apple_golden...  ...  [4.973411570365238, 5.106126648049519, 0.04110...
# 3108  s3://projetfruits/data/input/Test/apple_red_ye...  ...  [-0.2985779928663367, -2.5583979692025993, 3.1...
# 3109  s3://projetfruits/data/input/Test/zucchini_1/r...  ...  [6.599532008598656, -2.6852302544316555, -7.82...
#
# [3110 rows x 3 columns]

# %%
print(spark.sparkContext.getConf().get("spark.driver.host"))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ip-172-31-41-180.eu-west-3.compute.internal

# %%
configurations = spark.sparkContext.getConf().getAll()
for item in configurations: print(item)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('spark.eventLog.enabled', 'true')
# ('spark.executor.memory', '9486M')
# ('spark.yarn.app.container.log.dir', '/var/log/hadoop-yarn/containers/application_1687080233630_0001/container_1687080233630_0001_01_000001')
# ('spark.app.id', 'application_1687080233630_0001')
# ('spark.driver.extraJavaOptions', "-XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -XX:OnOutOfMemoryError='kill -9 %p'")
# ('spark.sql.parquet.output.committer.class', 'com.amazon.emr.committer.EmrOptimizedSparkSqlParquetOutputCommitter')
# ('spark.blacklist.decommissioning.timeout', '1h')
# ('spark.app.startTime', '1687081840995')
# ('spark.yarn.appMasterEnv.SPARK_PUBLIC_DNS', '$(hostname -f)')
# ('spark.repl.class.outputDir', '/mnt1/yarn/usercache/livy/appcache/application_1687080233630_0001/container_1687080233630_0001_01_000001/tmp/spark4222835514967862390')
# ('spark.sql.emr.internal.extensions', 'com.amazonaws.emr.spark.EmrSparkSessionExtensions')
# ('spark.driver.host', 'ip-172-31-41-180.eu-west-3.compute.internal')
# ('spark.eventLog.dir', 'hdfs:///var/log/spark/apps')
# ('spark.yarn.historyServer.address', 'ip-172-31-41-89.eu-west-3.compute.internal:18080')
# ('spark.yarn.heterogeneousExecutors.enabled', 'false')
# ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_URI_BASES', 'http://ip-172-31-41-89.eu-west-3.compute.internal:20888/proxy/application_1687080233630_0001')
# ('spark.history.fs.logDirectory', 'hdfs:///var/log/spark/apps')
# ('spark.ui.filters', 'org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter')
# ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_HOSTS', 'ip-172-31-41-89.eu-west-3.compute.internal')
# ('spark.executor.extraLibraryPath', '/usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native:/docker/usr/lib/hadoop/lib/native:/docker/usr/lib/hadoop-lzo/lib/native')
# ('spark.hadoop.yarn.timeline-service.enabled', 'false')
# ('spark.executor.id', 'driver')
# ('spark.driver.extraClassPath', '/usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar:/docker/usr/lib/hadoop-lzo/lib/*:/docker/usr/lib/hadoop/hadoop-aws.jar:/docker/usr/share/aws/aws-java-sdk/*:/docker/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/docker/usr/share/aws/emr/security/conf:/docker/usr/share/aws/emr/security/lib/*:/docker/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/docker/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/docker/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/docker/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar')
# ('spark.executorEnv.PYTHONPATH', '{{PWD}}/pyspark.zip<CPS>{{PWD}}/py4j-0.10.9.5-src.zip')
# ('spark.yarn.dist.jars', 'file:///usr/lib/livy/rsc-jars/arpack_combined_all-0.1.jar,file:///usr/lib/livy/rsc-jars/core-1.1.2.jar,file:///usr/lib/livy/rsc-jars/jniloader-1.1.jar,file:///usr/lib/livy/rsc-jars/livy-api-0.7.1-incubating.jar,file:///usr/lib/livy/rsc-jars/livy-rsc-0.7.1-incubating.jar,file:///usr/lib/livy/rsc-jars/livy-thriftserver-session-0.7.1-incubating.jar,file:///usr/lib/livy/rsc-jars/native_ref-java-1.1.jar,file:///usr/lib/livy/rsc-jars/native_system-java-1.1.jar,file:///usr/lib/livy/rsc-jars/netlib-native_ref-linux-armhf-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_ref-linux-i686-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_ref-linux-x86_64-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_ref-osx-x86_64-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_ref-win-i686-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_ref-win-x86_64-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_system-linux-armhf-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_system-linux-i686-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_system-linux-x86_64-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_system-osx-x86_64-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_system-win-i686-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netlib-native_system-win-x86_64-1.1-natives.jar,file:///usr/lib/livy/rsc-jars/netty-all-4.1.17.Final.jar,file:///usr/lib/livy/repl_2.12-jars/commons-codec-1.9.jar,file:///usr/lib/livy/repl_2.12-jars/livy-core_2.12-0.7.1-incubating.jar,file:///usr/lib/livy/repl_2.12-jars/livy-repl_2.12-0.7.1-incubating.jar')
# ('spark.hadoop.mapreduce.output.fs.optimized.committer.enabled', 'true')
# ('spark.decommissioning.timeout.threshold', '20')
# ('spark.sql.catalogImplementation', 'hive')
# ('spark.yarn.dist.pyFiles', '')
# ('spark.stage.attempt.ignoreOnDecommissionFetchFailure', 'true')
# ('spark.hadoop.fs.s3.getObject.initialSocketTimeoutMilliseconds', '2000')
# ('spark.driver.memory', '1000M')
# ('spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version.emr_internal_use_only.EmrFileSystem', '2')
# ('spark.submit.deployMode', 'cluster')
# ('spark.yarn.dist.files', 'file:/etc/spark/conf.dist/hive-site.xml,file:/etc/hudi/conf.dist/hudi-defaults.conf')
# ('spark.yarn.submit.waitAppCompletion', 'false')
# ('spark.yarn.app.id', 'application_1687080233630_0001')
# ('spark.yarn.dist.archives', 'file:/usr/lib/spark/R/lib/sparkr.zip#sparkr')
# ('spark.repl.class.uri', 'spark://ip-172-31-41-180.eu-west-3.compute.internal:32785/classes')
# ('spark.yarn.maxAppAttempts', '1')
# ('spark.driver.port', '32785')
# ('spark.sql.hive.metastore.sharedPrefixes', 'com.amazonaws.services.dynamodbv2')
# ('spark.app.attempt.id', '1')
# ('spark.yarn.secondary.jars', 'arpack_combined_all-0.1.jar,core-1.1.2.jar,jniloader-1.1.jar,livy-api-0.7.1-incubating.jar,livy-rsc-0.7.1-incubating.jar,livy-thriftserver-session-0.7.1-incubating.jar,native_ref-java-1.1.jar,native_system-java-1.1.jar,netlib-native_ref-linux-armhf-1.1-natives.jar,netlib-native_ref-linux-i686-1.1-natives.jar,netlib-native_ref-linux-x86_64-1.1-natives.jar,netlib-native_ref-osx-x86_64-1.1-natives.jar,netlib-native_ref-win-i686-1.1-natives.jar,netlib-native_ref-win-x86_64-1.1-natives.jar,netlib-native_system-linux-armhf-1.1-natives.jar,netlib-native_system-linux-i686-1.1-natives.jar,netlib-native_system-linux-x86_64-1.1-natives.jar,netlib-native_system-osx-x86_64-1.1-natives.jar,netlib-native_system-win-i686-1.1-natives.jar,netlib-native_system-win-x86_64-1.1-natives.jar,netty-all-4.1.17.Final.jar,commons-codec-1.9.jar,livy-core_2.12-0.7.1-incubating.jar,livy-repl_2.12-0.7.1-incubating.jar')
# ('spark.yarn.tags', 'livy-session-0-V36eOeRB')
# ('spark.sql.parquet.fs.optimized.committer.optimization-enabled', 'true')
# ('spark.driver.extraLibraryPath', '/usr/lib/hadoop/lib/native:/usr/lib/hadoop-lzo/lib/native:/docker/usr/lib/hadoop/lib/native:/docker/usr/lib/hadoop-lzo/lib/native')
# ('spark.hadoop.mapreduce.fileoutputcommitter.cleanup-failures.ignored.emr_internal_use_only.EmrFileSystem', 'true')
# ('spark.livy.spark_major_version', '3')
# ('spark.executor.extraClassPath', '/usr/lib/hadoop-lzo/lib/*:/usr/lib/hadoop/hadoop-aws.jar:/usr/share/aws/aws-java-sdk/*:/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/usr/share/aws/emr/security/conf:/usr/share/aws/emr/security/lib/*:/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar:/docker/usr/lib/hadoop-lzo/lib/*:/docker/usr/lib/hadoop/hadoop-aws.jar:/docker/usr/share/aws/aws-java-sdk/*:/docker/usr/share/aws/emr/goodies/lib/emr-spark-goodies.jar:/docker/usr/share/aws/emr/security/conf:/docker/usr/share/aws/emr/security/lib/*:/docker/usr/share/aws/hmclient/lib/aws-glue-datacatalog-spark-client.jar:/docker/usr/share/java/Hive-JSON-Serde/hive-openx-serde.jar:/docker/usr/share/aws/sagemaker-spark-sdk/lib/sagemaker-spark-sdk.jar:/docker/usr/share/aws/emr/s3select/lib/emr-s3-select-spark-connector.jar')
# ('spark.app.submitTime', '1687081806430')
# ('spark.history.ui.port', '18080')
# ('spark.shuffle.service.enabled', 'true')
# ('spark.driver.defaultJavaOptions', "-XX:OnOutOfMemoryError='kill -9 %p'")
# ('spark.resourceManager.cleanupExpiredHost', 'true')
# ('spark.executor.defaultJavaOptions', "-verbose:gc -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:OnOutOfMemoryError='kill -9 %p'")
# ('spark.executor.cores', '2')
# ('spark.app.name', 'livy-session-0')
# ('spark.sql.warehouse.dir', 'hdfs://ip-172-31-41-89.eu-west-3.compute.internal:8020/user/spark/warehouse')
# ('spark.files.fetchFailure.unRegisterOutputOnHost', 'true')
# ('spark.master', 'yarn')
# ('spark.ui.port', '0')
# ('spark.emr.default.executor.memory', '9486M')
# ('spark.executor.extraJavaOptions', "-XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -verbose:gc -XX:+PrintGCDetails -XX:+PrintGCDateStamps -XX:OnOutOfMemoryError='kill -9 %p'")
# ('spark.submit.pyFiles', '')
# ('spark.dynamicAllocation.enabled', 'true')
# ('spark.yarn.isPython', 'true')
# ('spark.emr.default.executor.cores', '4')
# ('spark.blacklist.decommissioning.enabled', 'true')

# %% [markdown]
# # Test save au format csv Features

# %%
from pyspark.sql.functions import udf
from pyspark.ml.linalg import Vectors
from pyspark.sql.functions import col,lit
from pyspark.sql.types import StringType, FloatType

# %%
df = spark.read.parquet(PATH_Result)

# %%
df.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- features: array (nullable = true)
#  |    |-- element: float (containsNull = true)

# %%
df.show()
# Out:
# +--------------------+-----------+--------------------+
# |                path|      label|            features|
# +--------------------+-----------+--------------------+
# |file:/home/daipc/...|     pear_1|[0.65473557, 0.17...|
# |file:/home/daipc/...|     pear_1|[1.2782416, 0.171...|
# |file:/home/daipc/...| zucchini_1|[0.0, 0.46113133,...|
# |file:/home/daipc/...| zucchini_1|[0.0, 0.6455605, ...|
# |file:/home/daipc/...|     pear_1|[0.6565265, 0.245...|
# |file:/home/daipc/...| zucchini_1|[0.18821537, 0.84...|
# |file:/home/daipc/...|     pear_1|[0.22975095, 0.30...|
# |file:/home/daipc/...|     pear_1|[2.0570443, 0.408...|
# |file:/home/daipc/...| zucchini_1|[0.0, 0.50699013,...|
# |file:/home/daipc/...| zucchini_1|[0.0, 0.6695162, ...|
# |file:/home/daipc/...|     pear_1|[2.3288968, 0.070...|
# |file:/home/daipc/...| zucchini_1|[0.0, 0.2755962, ...|
# |file:/home/daipc/...|     pear_1|[1.5394454, 0.438...|
# |file:/home/daipc/...|     pear_1|[1.4804848, 0.192...|
# |file:/home/daipc/...|     pear_1|[0.45501274, 0.02...|
# |file:/home/daipc/...|apple_red_2|[1.0250626, 0.026...|
# |file:/home/daipc/...|     pear_1|[2.133239, 0.4431...|
# |file:/home/daipc/...|apple_red_2|[1.4586371, 0.0, ...|
# |file:/home/daipc/...|     pear_1|[0.62109387, 0.00...|
# |file:/home/daipc/...|apple_red_2|[0.19252966, 0.27...|
# +--------------------+-----------+--------------------+
# only showing top 20 rows

# %%
# Nombre de features : 
num_features = len(df.select("features").first()[0]) 
num_features
# Out:
# 1280

# %%
# Extraction des composante avec udf function
extract_features = udf(lambda x, i: float(x[i]), FloatType())

# %%
extract_features
# Out:
# <function __main__.<lambda>(x, i)>

# %%
for i in range(num_features):
    df = df.withColumn(f"feature_{i+1}", extract_features("features", lit(i)))

# %%
df.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- features: array (nullable = true)
#  |    |-- element: float (containsNull = true)
#  |-- component_1: float (nullable = true)
#  |-- component_2: float (nullable = true)
#  |-- component_3: float (nullable = true)
#  |-- component_4: float (nullable = true)
#  |-- component_5: float (nullable = true)
#  |-- component_6: float (nullable = true)
#  |-- component_7: float (nullable = true)
#  |-- component_8: float (nullable = true)
#  |-- component_9: float (nullable = true)
#  |-- component_10: float (nullable = true)
#  |-- component_11: float (nullable = true)
#  |-- component_12: float (nullable = true)
#  |-- component_13: float (nullable = true)
#  |-- component_14: float (nullable = true)
#  |-- component_15: float (nullable = true)
#  |-- component_16: float (nullable = true)
#  |-- component_17: float (nullable = true)
#  |-- component_18: float (nullable = true)
#  |-- component_19: float (nullable = true)
#  |-- component_20: float (nullable = true)
#  |-- component_21: float (nullable = true)
#  |-- component_22: float (nullable = true)
#  |-- component_23: float (nullable = true)
#  |-- component_24: float (nullable = true)
#  |-- component_25: float (nullable = true)
#  |-- component_26: float (nullable = true)
#  |-- component_27: float (nullable = true)
#  |-- component_28: float (nullable = true)
#  |-- component_29: float (nullable = true)
#  |-- component_30: float (nullable = true)
#  |-- component_31: float (nullable = true)
#  |-- component_32: float (nullable = true)
#  |-- component_33: float (nullable = true)
#  |-- component_34: float (nullable = true)
#  |-- component_35: float (nullable = true)
#  |-- component_36: float (nullable = true)
#  |-- component_37: float (nullable = true)
#  |-- component_38: float (nullable = true)
#  |-- component_39: float (nullable = true)
#  |-- component_40: float (nullable = true)
#  |-- component_41: float (nullable = true)
#  |-- component_42: float (nullable = true)
#  |-- component_43: float (nullable = true)
#  |-- component_44: float (nullable = true)
#  |-- component_45: float (nullable = true)
#  |-- component_46: float (nullable = true)
#  |-- component_47: float (nullable = true)
#  |-- component_48: float (nullable = true)
#  |-- component_49: float (nullable = true)
#  |-- component_50: float (nullable = true)
#  |-- component_51: float (nullable = true)
#  |-- component_52: float (nullable = true)
#  |-- component_53: float (nullable = true)
#  |-- component_54: float (nullable = true)
#  |-- component_55: float (nullable = true)
#  |-- component_56: float (nullable = true)
#  |-- component_57: float (nullable = true)
#  |-- component_58: float (nullable = true)
#  |-- component_59: float (nullable = true)
#  |-- component_60: float (nullable = true)
#  |-- component_61: float (nullable = true)
#  |-- component_62: float (nullable = true)
#  |-- component_63: float (nullable = true)
#  |-- component_64: float (nullable = true)
#  |-- component_65: float (nullable = true)
#  |-- component_66: float (nullable = true)
#  |-- component_67: float (nullable = true)
#  |-- component_68: float (nullable = true)
#  |-- component_69: float (nullable = true)
#  |-- component_70: float (nullable = true)
#  |-- component_71: float (nullable = true)
#  |-- component_72: float (nullable = true)
#  |-- component_73: float (nullable = true)
#  |-- component_74: float (nullable = true)
#  |-- component_75: float (nullable = true)
#  |-- component_76: float (nullable = true)
#  |-- component_77: float (nullable = true)
#  |-- component_78: float (nullable = true)
#  |-- component_79: float (nullable = true)
#  |-- component_80: float (nullable = true)
#  |-- component_81: float (nullable = true)
#  |-- component_82: float (nullable = true)
#  |-- component_83: float (nullable = true)
#  |-- component_84: float (nullable = true)
#  |-- component_85: float (nullable = true)
#  |-- component_86: float (nullable = true)
#  |-- component_87: float (nullable = true)
#  |-- component_88: float (nullable = true)
#  |-- component_89: float (nullable = true)
#  |-- component_90: float (nullable = true)
#  |-- component_91: float (nullable = true)
#  |-- component_92: float (nullable = true)
#  |-- component_93: float (nullable = true)
#  |-- component_94: float (nullable = true)
#  |-- component_95: float (nullable = true)
#  |-- component_96: float (nullable = true)
#  |-- component_97: float (nullable = true)
#  |-- component_98: float (nullable = true)
#  |-- component_99: float (nullable = true)
#  |-- component_100: float (nullable = true)
#  |-- component_101: float (nullable = true)
#  |-- component_102: float (nullable = true)
#  |-- component_103: float (nullable = true)
#  |-- component_104: float (nullable = true)
#  |-- component_105: float (nullable = true)
#  |-- component_106: float (nullable = true)
#  |-- component_107: float (nullable = true)
#  |-- component_108: float (nullable = true)
#  |-- component_109: float (nullable = true)
#  |-- component_110: float (nullable = true)
#  |-- component_111: float (nullable = true)
#  |-- component_112: float (nullable = true)
#  |-- component_113: float (nullable = true)
#  |-- component_114: float (nullable = true)
#  |-- component_115: float (nullable = true)
#  |-- component_116: float (nullable = true)
#  |-- component_117: float (nullable = true)
#  |-- component_118: float (nullable = true)
#  |-- component_119: float (nullable = true)
#  |-- component_120: float (nullable = true)
#  |-- component_121: float (nullable = true)
#  |-- component_122: float (nullable = true)
#  |-- component_123: float (nullable = true)
#  |-- component_124: float (nullable = true)
#  |-- component_125: float (nullable = true)
#  |-- component_126: float (nullable = true)
#  |-- component_127: float (nullable = true)
#  |-- component_128: float (nullable = true)
#  |-- component_129: float (nullable = true)
#  |-- component_130: float (nullable = true)
#  |-- component_131: float (nullable = true)
#  |-- component_132: float (nullable = true)
#  |-- component_133: float (nullable = true)
#  |-- component_134: float (nullable = true)
#  |-- component_135: float (nullable = true)
#  |-- component_136: float (nullable = true)
#  |-- component_137: float (nullable = true)
#  |-- component_138: float (nullable = true)
#  |-- component_139: float (nullable = true)
#  |-- component_140: float (nullable = true)
#  |-- component_141: float (nullable = true)
#  |-- component_142: float (nullable = true)
#  |-- component_143: float (nullable = true)
#  |-- component_144: float (nullable = true)
#  |-- component_145: float (nullable = true)
#  |-- component_146: float (nullable = true)
#  |-- component_147: float (nullable = true)
#  |-- component_148: float (nullable = true)
#  |-- component_149: float (nullable = true)
#  |-- component_150: float (nullable = true)
#  |-- component_151: float (nullable = true)
#  |-- component_152: float (nullable = true)
#  |-- component_153: float (nullable = true)
#  |-- component_154: float (nullable = true)
#  |-- component_155: float (nullable = true)
#  |-- component_156: float (nullable = true)
#  |-- component_157: float (nullable = true)
#  |-- component_158: float (nullable = true)
#  |-- component_159: float (nullable = true)
#  |-- component_160: float (nullable = true)
#  |-- component_161: float (nullable = true)
#  |-- component_162: float (nullable = true)
#  |-- component_163: float (nullable = true)
#  |-- component_164: float (nullable = true)
#  |-- component_165: float (nullable = true)
#  |-- component_166: float (nullable = true)
#  |-- component_167: float (nullable = true)
#  |-- component_168: float (nullable = true)
#  |-- component_169: float (nullable = true)
#  |-- component_170: float (nullable = true)
#  |-- component_171: float (nullable = true)
#  |-- component_172: float (nullable = true)
#  |-- component_173: float (nullable = true)
#  |-- component_174: float (nullable = true)
#  |-- component_175: float (nullable = true)
#  |-- component_176: float (nullable = true)
#  |-- component_177: float (nullable = true)
#  |-- component_178: float (nullable = true)
#  |-- component_179: float (nullable = true)
#  |-- component_180: float (nullable = true)
#  |-- component_181: float (nullable = true)
#  |-- component_182: float (nullable = true)
#  |-- component_183: float (nullable = true)
#  |-- component_184: float (nullable = true)
#  |-- component_185: float (nullable = true)
#  |-- component_186: float (nullable = true)
#  |-- component_187: float (nullable = true)
#  |-- component_188: float (nullable = true)
#  |-- component_189: float (nullable = true)
#  |-- component_190: float (nullable = true)
#  |-- component_191: float (nullable = true)
#  |-- component_192: float (nullable = true)
#  |-- component_193: float (nullable = true)
#  |-- component_194: float (nullable = true)
#  |-- component_195: float (nullable = true)
#  |-- component_196: float (nullable = true)
#  |-- component_197: float (nullable = true)
#  |-- component_198: float (nullable = true)
#  |-- component_199: float (nullable = true)
#  |-- component_200: float (nullable = true)
#  |-- component_201: float (nullable = true)
#  |-- component_202: float (nullable = true)
#  |-- component_203: float (nullable = true)
#  |-- component_204: float (nullable = true)
#  |-- component_205: float (nullable = true)
#  |-- component_206: float (nullable = true)
#  |-- component_207: float (nullable = true)
#  |-- component_208: float (nullable = true)
#  |-- component_209: float (nullable = true)
#  |-- component_210: float (nullable = true)
#  |-- component_211: float (nullable = true)
#  |-- component_212: float (nullable = true)
#  |-- component_213: float (nullable = true)
#  |-- component_214: float (nullable = true)
#  |-- component_215: float (nullable = true)
#  |-- component_216: float (nullable = true)
#  |-- component_217: float (nullable = true)
#  |-- component_218: float (nullable = true)
#  |-- component_219: float (nullable = true)
#  |-- component_220: float (nullable = true)
#  |-- component_221: float (nullable = true)
#  |-- component_222: float (nullable = true)
#  |-- component_223: float (nullable = true)
#  |-- component_224: float (nullable = true)
#  |-- component_225: float (nullable = true)
#  |-- component_226: float (nullable = true)
#  |-- component_227: float (nullable = true)
#  |-- component_228: float (nullable = true)
#  |-- component_229: float (nullable = true)
#  |-- component_230: float (nullable = true)
#  |-- component_231: float (nullable = true)
#  |-- component_232: float (nullable = true)
#  |-- component_233: float (nullable = true)
#  |-- component_234: float (nullable = true)
#  |-- component_235: float (nullable = true)
#  |-- component_236: float (nullable = true)
#  |-- component_237: float (nullable = true)
#  |-- component_238: float (nullable = true)
#  |-- component_239: float (nullable = true)
#  |-- component_240: float (nullable = true)
#  |-- component_241: float (nullable = true)
#  |-- component_242: float (nullable = true)
#  |-- component_243: float (nullable = true)
#  |-- component_244: float (nullable = true)
#  |-- component_245: float (nullable = true)
#  |-- component_246: float (nullable = true)
#  |-- component_247: float (nullable = true)
#  |-- component_248: float (nullable = true)
#  |-- component_249: float (nullable = true)
#  |-- component_250: float (nullable = true)
#  |-- component_251: float (nullable = true)
#  |-- component_252: float (nullable = true)
#  |-- component_253: float (nullable = true)
#  |-- component_254: float (nullable = true)
#  |-- component_255: float (nullable = true)
#  |-- component_256: float (nullable = true)
#  |-- component_257: float (nullable = true)
#  |-- component_258: float (nullable = true)
#  |-- component_259: float (nullable = true)
#  |-- component_260: float (nullable = true)
#  |-- component_261: float (nullable = true)
#  |-- component_262: float (nullable = true)
#  |-- component_263: float (nullable = true)
#  |-- component_264: float (nullable = true)
#  |-- component_265: float (nullable = true)
#  |-- component_266: float (nullable = true)
#  |-- component_267: float (nullable = true)
#  |-- component_268: float (nullable = true)
#  |-- component_269: float (nullable = true)
#  |-- component_270: float (nullable = true)
#  |-- component_271: float (nullable = true)
#  |-- component_272: float (nullable = true)
#  |-- component_273: float (nullable = true)
#  |-- component_274: float (nullable = true)
#  |-- component_275: float (nullable = true)
#  |-- component_276: float (nullable = true)
#  |-- component_277: float (nullable = true)
#  |-- component_278: float (nullable = true)
#  |-- component_279: float (nullable = true)
#  |-- component_280: float (nullable = true)
#  |-- component_281: float (nullable = true)
#  |-- component_282: float (nullable = true)
#  |-- component_283: float (nullable = true)
#  |-- component_284: float (nullable = true)
#  |-- component_285: float (nullable = true)
#  |-- component_286: float (nullable = true)
#  |-- component_287: float (nullable = true)
#  |-- component_288: float (nullable = true)
#  |-- component_289: float (nullable = true)
#  |-- component_290: float (nullable = true)
#  |-- component_291: float (nullable = true)
#  |-- component_292: float (nullable = true)
#  |-- component_293: float (nullable = true)
#  |-- component_294: float (nullable = true)
#  |-- component_295: float (nullable = true)
#  |-- component_296: float (nullable = true)
#  |-- component_297: float (nullable = true)
#  |-- component_298: float (nullable = true)
#  |-- component_299: float (nullable = true)
#  |-- component_300: float (nullable = true)
#  |-- component_301: float (nullable = true)
#  |-- component_302: float (nullable = true)
#  |-- component_303: float (nullable = true)
#  |-- component_304: float (nullable = true)
#  |-- component_305: float (nullable = true)
#  |-- component_306: float (nullable = true)
#  |-- component_307: float (nullable = true)
#  |-- component_308: float (nullable = true)
#  |-- component_309: float (nullable = true)
#  |-- component_310: float (nullable = true)
#  |-- component_311: float (nullable = true)
#  |-- component_312: float (nullable = true)
#  |-- component_313: float (nullable = true)
#  |-- component_314: float (nullable = true)
#  |-- component_315: float (nullable = true)
#  |-- component_316: float (nullable = true)
#  |-- component_317: float (nullable = true)
#  |-- component_318: float (nullable = true)
#  |-- component_319: float (nullable = true)
#  |-- component_320: float (nullable = true)
#  |-- component_321: float (nullable = true)
#  |-- component_322: float (nullable = true)
#  |-- component_323: float (nullable = true)
#  |-- component_324: float (nullable = true)
#  |-- component_325: float (nullable = true)
#  |-- component_326: float (nullable = true)
#  |-- component_327: float (nullable = true)
#  |-- component_328: float (nullable = true)
#  |-- component_329: float (nullable = true)
#  |-- component_330: float (nullable = true)
#  |-- component_331: float (nullable = true)
#  |-- component_332: float (nullable = true)
#  |-- component_333: float (nullable = true)
#  |-- component_334: float (nullable = true)
#  |-- component_335: float (nullable = true)
#  |-- component_336: float (nullable = true)
#  |-- component_337: float (nullable = true)
#  |-- component_338: float (nullable = true)
#  |-- component_339: float (nullable = true)
#  |-- component_340: float (nullable = true)
#  |-- component_341: float (nullable = true)
#  |-- component_342: float (nullable = true)
#  |-- component_343: float (nullable = true)
#  |-- component_344: float (nullable = true)
#  |-- component_345: float (nullable = true)
#  |-- component_346: float (nullable = true)
#  |-- component_347: float (nullable = true)
#  |-- component_348: float (nullable = true)
#  |-- component_349: float (nullable = true)
#  |-- component_350: float (nullable = true)
#  |-- component_351: float (nullable = true)
#  |-- component_352: float (nullable = true)
#  |-- component_353: float (nullable = true)
#  |-- component_354: float (nullable = true)
#  |-- component_355: float (nullable = true)
#  |-- component_356: float (nullable = true)
#  |-- component_357: float (nullable = true)
#  |-- component_358: float (nullable = true)
#  |-- component_359: float (nullable = true)
#  |-- component_360: float (nullable = true)
#  |-- component_361: float (nullable = true)
#  |-- component_362: float (nullable = true)
#  |-- component_363: float (nullable = true)
#  |-- component_364: float (nullable = true)
#  |-- component_365: float (nullable = true)
#  |-- component_366: float (nullable = true)
#  |-- component_367: float (nullable = true)
#  |-- component_368: float (nullable = true)
#  |-- component_369: float (nullable = true)
#  |-- component_370: float (nullable = true)
#  |-- component_371: float (nullable = true)
#  |-- component_372: float (nullable = true)
#  |-- component_373: float (nullable = true)
#  |-- component_374: float (nullable = true)
#  |-- component_375: float (nullable = true)
#  |-- component_376: float (nullable = true)
#  |-- component_377: float (nullable = true)
#  |-- component_378: float (nullable = true)
#  |-- component_379: float (nullable = true)
#  |-- component_380: float (nullable = true)
#  |-- component_381: float (nullable = true)
#  |-- component_382: float (nullable = true)
#  |-- component_383: float (nullable = true)
#  |-- component_384: float (nullable = true)
#  |-- component_385: float (nullable = true)
#  |-- component_386: float (nullable = true)
#  |-- component_387: float (nullable = true)
#  |-- component_388: float (nullable = true)
#  |-- component_389: float (nullable = true)
#  |-- component_390: float (nullable = true)
#  |-- component_391: float (nullable = true)
#  |-- component_392: float (nullable = true)
#  |-- component_393: float (nullable = true)
#  |-- component_394: float (nullable = true)
#  |-- component_395: float (nullable = true)
#  |-- component_396: float (nullable = true)
#  |-- component_397: float (nullable = true)
#  |-- component_398: float (nullable = true)
#  |-- component_399: float (nullable = true)
#  |-- component_400: float (nullable = true)
#  |-- component_401: float (nullable = true)
#  |-- component_402: float (nullable = true)
#  |-- component_403: float (nullable = true)
#  |-- component_404: float (nullable = true)
#  |-- component_405: float (nullable = true)
#  |-- component_406: float (nullable = true)
#  |-- component_407: float (nullable = true)
#  |-- component_408: float (nullable = true)
#  |-- component_409: float (nullable = true)
#  |-- component_410: float (nullable = true)
#  |-- component_411: float (nullable = true)
#  |-- component_412: float (nullable = true)
#  |-- component_413: float (nullable = true)
#  |-- component_414: float (nullable = true)
#  |-- component_415: float (nullable = true)
#  |-- component_416: float (nullable = true)
#  |-- component_417: float (nullable = true)
#  |-- component_418: float (nullable = true)
#  |-- component_419: float (nullable = true)
#  |-- component_420: float (nullable = true)
#  |-- component_421: float (nullable = true)
#  |-- component_422: float (nullable = true)
#  |-- component_423: float (nullable = true)
#  |-- component_424: float (nullable = true)
#  |-- component_425: float (nullable = true)
#  |-- component_426: float (nullable = true)
#  |-- component_427: float (nullable = true)
#  |-- component_428: float (nullable = true)
#  |-- component_429: float (nullable = true)
#  |-- component_430: float (nullable = true)
#  |-- component_431: float (nullable = true)
#  |-- component_432: float (nullable = true)
#  |-- component_433: float (nullable = true)
#  |-- component_434: float (nullable = true)
#  |-- component_435: float (nullable = true)
#  |-- component_436: float (nullable = true)
#  |-- component_437: float (nullable = true)
#  |-- component_438: float (nullable = true)
#  |-- component_439: float (nullable = true)
#  |-- component_440: float (nullable = true)
#  |-- component_441: float (nullable = true)
#  |-- component_442: float (nullable = true)
#  |-- component_443: float (nullable = true)
#  |-- component_444: float (nullable = true)
#  |-- component_445: float (nullable = true)
#  |-- component_446: float (nullable = true)
#  |-- component_447: float (nullable = true)
#  |-- component_448: float (nullable = true)
#  |-- component_449: float (nullable = true)
#  |-- component_450: float (nullable = true)
#  |-- component_451: float (nullable = true)
#  |-- component_452: float (nullable = true)
#  |-- component_453: float (nullable = true)
#  |-- component_454: float (nullable = true)
#  |-- component_455: float (nullable = true)
#  |-- component_456: float (nullable = true)
#  |-- component_457: float (nullable = true)
#  |-- component_458: float (nullable = true)
#  |-- component_459: float (nullable = true)
#  |-- component_460: float (nullable = true)
#  |-- component_461: float (nullable = true)
#  |-- component_462: float (nullable = true)
#  |-- component_463: float (nullable = true)
#  |-- component_464: float (nullable = true)
#  |-- component_465: float (nullable = true)
#  |-- component_466: float (nullable = true)
#  |-- component_467: float (nullable = true)
#  |-- component_468: float (nullable = true)
#  |-- component_469: float (nullable = true)
#  |-- component_470: float (nullable = true)
#  |-- component_471: float (nullable = true)
#  |-- component_472: float (nullable = true)
#  |-- component_473: float (nullable = true)
#  |-- component_474: float (nullable = true)
#  |-- component_475: float (nullable = true)
#  |-- component_476: float (nullable = true)
#  |-- component_477: float (nullable = true)
#  |-- component_478: float (nullable = true)
#  |-- component_479: float (nullable = true)
#  |-- component_480: float (nullable = true)
#  |-- component_481: float (nullable = true)
#  |-- component_482: float (nullable = true)
#  |-- component_483: float (nullable = true)
#  |-- component_484: float (nullable = true)
#  |-- component_485: float (nullable = true)
#  |-- component_486: float (nullable = true)
#  |-- component_487: float (nullable = true)
#  |-- component_488: float (nullable = true)
#  |-- component_489: float (nullable = true)
#  |-- component_490: float (nullable = true)
#  |-- component_491: float (nullable = true)
#  |-- component_492: float (nullable = true)
#  |-- component_493: float (nullable = true)
#  |-- component_494: float (nullable = true)
#  |-- component_495: float (nullable = true)
#  |-- component_496: float (nullable = true)
#  |-- component_497: float (nullable = true)
#  |-- component_498: float (nullable = true)
#  |-- component_499: float (nullable = true)
#  |-- component_500: float (nullable = true)
#  |-- component_501: float (nullable = true)
#  |-- component_502: float (nullable = true)
#  |-- component_503: float (nullable = true)
#  |-- component_504: float (nullable = true)
#  |-- component_505: float (nullable = true)
#  |-- component_506: float (nullable = true)
#  |-- component_507: float (nullable = true)
#  |-- component_508: float (nullable = true)
#  |-- component_509: float (nullable = true)
#  |-- component_510: float (nullable = true)
#  |-- component_511: float (nullable = true)
#  |-- component_512: float (nullable = true)
#  |-- component_513: float (nullable = true)
#  |-- component_514: float (nullable = true)
#  |-- component_515: float (nullable = true)
#  |-- component_516: float (nullable = true)
#  |-- component_517: float (nullable = true)
#  |-- component_518: float (nullable = true)
#  |-- component_519: float (nullable = true)
#  |-- component_520: float (nullable = true)
#  |-- component_521: float (nullable = true)
#  |-- component_522: float (nullable = true)
#  |-- component_523: float (nullable = true)
#  |-- component_524: float (nullable = true)
#  |-- component_525: float (nullable = true)
#  |-- component_526: float (nullable = true)
#  |-- component_527: float (nullable = true)
#  |-- component_528: float (nullable = true)
#  |-- component_529: float (nullable = true)
#  |-- component_530: float (nullable = true)
#  |-- component_531: float (nullable = true)
#  |-- component_532: float (nullable = true)
#  |-- component_533: float (nullable = true)
#  |-- component_534: float (nullable = true)
#  |-- component_535: float (nullable = true)
#  |-- component_536: float (nullable = true)
#  |-- component_537: float (nullable = true)
#  |-- component_538: float (nullable = true)
#  |-- component_539: float (nullable = true)
#  |-- component_540: float (nullable = true)
#  |-- component_541: float (nullable = true)
#  |-- component_542: float (nullable = true)
#  |-- component_543: float (nullable = true)
#  |-- component_544: float (nullable = true)
#  |-- component_545: float (nullable = true)
#  |-- component_546: float (nullable = true)
#  |-- component_547: float (nullable = true)
#  |-- component_548: float (nullable = true)
#  |-- component_549: float (nullable = true)
#  |-- component_550: float (nullable = true)
#  |-- component_551: float (nullable = true)
#  |-- component_552: float (nullable = true)
#  |-- component_553: float (nullable = true)
#  |-- component_554: float (nullable = true)
#  |-- component_555: float (nullable = true)
#  |-- component_556: float (nullable = true)
#  |-- component_557: float (nullable = true)
#  |-- component_558: float (nullable = true)
#  |-- component_559: float (nullable = true)
#  |-- component_560: float (nullable = true)
#  |-- component_561: float (nullable = true)
#  |-- component_562: float (nullable = true)
#  |-- component_563: float (nullable = true)
#  |-- component_564: float (nullable = true)
#  |-- component_565: float (nullable = true)
#  |-- component_566: float (nullable = true)
#  |-- component_567: float (nullable = true)
#  |-- component_568: float (nullable = true)
#  |-- component_569: float (nullable = true)
#  |-- component_570: float (nullable = true)
#  |-- component_571: float (nullable = true)
#  |-- component_572: float (nullable = true)
#  |-- component_573: float (nullable = true)
#  |-- component_574: float (nullable = true)
#  |-- component_575: float (nullable = true)
#  |-- component_576: float (nullable = true)
#  |-- component_577: float (nullable = true)
#  |-- component_578: float (nullable = true)
#  |-- component_579: float (nullable = true)
#  |-- component_580: float (nullable = true)
#  |-- component_581: float (nullable = true)
#  |-- component_582: float (nullable = true)
#  |-- component_583: float (nullable = true)
#  |-- component_584: float (nullable = true)
#  |-- component_585: float (nullable = true)
#  |-- component_586: float (nullable = true)
#  |-- component_587: float (nullable = true)
#  |-- component_588: float (nullable = true)
#  |-- component_589: float (nullable = true)
#  |-- component_590: float (nullable = true)
#  |-- component_591: float (nullable = true)
#  |-- component_592: float (nullable = true)
#  |-- component_593: float (nullable = true)
#  |-- component_594: float (nullable = true)
#  |-- component_595: float (nullable = true)
#  |-- component_596: float (nullable = true)
#  |-- component_597: float (nullable = true)
#  |-- component_598: float (nullable = true)
#  |-- component_599: float (nullable = true)
#  |-- component_600: float (nullable = true)
#  |-- component_601: float (nullable = true)
#  |-- component_602: float (nullable = true)
#  |-- component_603: float (nullable = true)
#  |-- component_604: float (nullable = true)
#  |-- component_605: float (nullable = true)
#  |-- component_606: float (nullable = true)
#  |-- component_607: float (nullable = true)
#  |-- component_608: float (nullable = true)
#  |-- component_609: float (nullable = true)
#  |-- component_610: float (nullable = true)
#  |-- component_611: float (nullable = true)
#  |-- component_612: float (nullable = true)
#  |-- component_613: float (nullable = true)
#  |-- component_614: float (nullable = true)
#  |-- component_615: float (nullable = true)
#  |-- component_616: float (nullable = true)
#  |-- component_617: float (nullable = true)
#  |-- component_618: float (nullable = true)
#  |-- component_619: float (nullable = true)
#  |-- component_620: float (nullable = true)
#  |-- component_621: float (nullable = true)
#  |-- component_622: float (nullable = true)
#  |-- component_623: float (nullable = true)
#  |-- component_624: float (nullable = true)
#  |-- component_625: float (nullable = true)
#  |-- component_626: float (nullable = true)
#  |-- component_627: float (nullable = true)
#  |-- component_628: float (nullable = true)
#  |-- component_629: float (nullable = true)
#  |-- component_630: float (nullable = true)
#  |-- component_631: float (nullable = true)
#  |-- component_632: float (nullable = true)
#  |-- component_633: float (nullable = true)
#  |-- component_634: float (nullable = true)
#  |-- component_635: float (nullable = true)
#  |-- component_636: float (nullable = true)
#  |-- component_637: float (nullable = true)
#  |-- component_638: float (nullable = true)
#  |-- component_639: float (nullable = true)
#  |-- component_640: float (nullable = true)
#  |-- component_641: float (nullable = true)
#  |-- component_642: float (nullable = true)
#  |-- component_643: float (nullable = true)
#  |-- component_644: float (nullable = true)
#  |-- component_645: float (nullable = true)
#  |-- component_646: float (nullable = true)
#  |-- component_647: float (nullable = true)
#  |-- component_648: float (nullable = true)
#  |-- component_649: float (nullable = true)
#  |-- component_650: float (nullable = true)
#  |-- component_651: float (nullable = true)
#  |-- component_652: float (nullable = true)
#  |-- component_653: float (nullable = true)
#  |-- component_654: float (nullable = true)
#  |-- component_655: float (nullable = true)
#  |-- component_656: float (nullable = true)
#  |-- component_657: float (nullable = true)
#  |-- component_658: float (nullable = true)
#  |-- component_659: float (nullable = true)
#  |-- component_660: float (nullable = true)
#  |-- component_661: float (nullable = true)
#  |-- component_662: float (nullable = true)
#  |-- component_663: float (nullable = true)
#  |-- component_664: float (nullable = true)
#  |-- component_665: float (nullable = true)
#  |-- component_666: float (nullable = true)
#  |-- component_667: float (nullable = true)
#  |-- component_668: float (nullable = true)
#  |-- component_669: float (nullable = true)
#  |-- component_670: float (nullable = true)
#  |-- component_671: float (nullable = true)
#  |-- component_672: float (nullable = true)
#  |-- component_673: float (nullable = true)
#  |-- component_674: float (nullable = true)
#  |-- component_675: float (nullable = true)
#  |-- component_676: float (nullable = true)
#  |-- component_677: float (nullable = true)
#  |-- component_678: float (nullable = true)
#  |-- component_679: float (nullable = true)
#  |-- component_680: float (nullable = true)
#  |-- component_681: float (nullable = true)
#  |-- component_682: float (nullable = true)
#  |-- component_683: float (nullable = true)
#  |-- component_684: float (nullable = true)
#  |-- component_685: float (nullable = true)
#  |-- component_686: float (nullable = true)
#  |-- component_687: float (nullable = true)
#  |-- component_688: float (nullable = true)
#  |-- component_689: float (nullable = true)
#  |-- component_690: float (nullable = true)
#  |-- component_691: float (nullable = true)
#  |-- component_692: float (nullable = true)
#  |-- component_693: float (nullable = true)
#  |-- component_694: float (nullable = true)
#  |-- component_695: float (nullable = true)
#  |-- component_696: float (nullable = true)
#  |-- component_697: float (nullable = true)
#  |-- component_698: float (nullable = true)
#  |-- component_699: float (nullable = true)
#  |-- component_700: float (nullable = true)
#  |-- component_701: float (nullable = true)
#  |-- component_702: float (nullable = true)
#  |-- component_703: float (nullable = true)
#  |-- component_704: float (nullable = true)
#  |-- component_705: float (nullable = true)
#  |-- component_706: float (nullable = true)
#  |-- component_707: float (nullable = true)
#  |-- component_708: float (nullable = true)
#  |-- component_709: float (nullable = true)
#  |-- component_710: float (nullable = true)
#  |-- component_711: float (nullable = true)
#  |-- component_712: float (nullable = true)
#  |-- component_713: float (nullable = true)
#  |-- component_714: float (nullable = true)
#  |-- component_715: float (nullable = true)
#  |-- component_716: float (nullable = true)
#  |-- component_717: float (nullable = true)
#  |-- component_718: float (nullable = true)
#  |-- component_719: float (nullable = true)
#  |-- component_720: float (nullable = true)
#  |-- component_721: float (nullable = true)
#  |-- component_722: float (nullable = true)
#  |-- component_723: float (nullable = true)
#  |-- component_724: float (nullable = true)
#  |-- component_725: float (nullable = true)
#  |-- component_726: float (nullable = true)
#  |-- component_727: float (nullable = true)
#  |-- component_728: float (nullable = true)
#  |-- component_729: float (nullable = true)
#  |-- component_730: float (nullable = true)
#  |-- component_731: float (nullable = true)
#  |-- component_732: float (nullable = true)
#  |-- component_733: float (nullable = true)
#  |-- component_734: float (nullable = true)
#  |-- component_735: float (nullable = true)
#  |-- component_736: float (nullable = true)
#  |-- component_737: float (nullable = true)
#  |-- component_738: float (nullable = true)
#  |-- component_739: float (nullable = true)
#  |-- component_740: float (nullable = true)
#  |-- component_741: float (nullable = true)
#  |-- component_742: float (nullable = true)
#  |-- component_743: float (nullable = true)
#  |-- component_744: float (nullable = true)
#  |-- component_745: float (nullable = true)
#  |-- component_746: float (nullable = true)
#  |-- component_747: float (nullable = true)
#  |-- component_748: float (nullable = true)
#  |-- component_749: float (nullable = true)
#  |-- component_750: float (nullable = true)
#  |-- component_751: float (nullable = true)
#  |-- component_752: float (nullable = true)
#  |-- component_753: float (nullable = true)
#  |-- component_754: float (nullable = true)
#  |-- component_755: float (nullable = true)
#  |-- component_756: float (nullable = true)
#  |-- component_757: float (nullable = true)
#  |-- component_758: float (nullable = true)
#  |-- component_759: float (nullable = true)
#  |-- component_760: float (nullable = true)
#  |-- component_761: float (nullable = true)
#  |-- component_762: float (nullable = true)
#  |-- component_763: float (nullable = true)
#  |-- component_764: float (nullable = true)
#  |-- component_765: float (nullable = true)
#  |-- component_766: float (nullable = true)
#  |-- component_767: float (nullable = true)
#  |-- component_768: float (nullable = true)
#  |-- component_769: float (nullable = true)
#  |-- component_770: float (nullable = true)
#  |-- component_771: float (nullable = true)
#  |-- component_772: float (nullable = true)
#  |-- component_773: float (nullable = true)
#  |-- component_774: float (nullable = true)
#  |-- component_775: float (nullable = true)
#  |-- component_776: float (nullable = true)
#  |-- component_777: float (nullable = true)
#  |-- component_778: float (nullable = true)
#  |-- component_779: float (nullable = true)
#  |-- component_780: float (nullable = true)
#  |-- component_781: float (nullable = true)
#  |-- component_782: float (nullable = true)
#  |-- component_783: float (nullable = true)
#  |-- component_784: float (nullable = true)
#  |-- component_785: float (nullable = true)
#  |-- component_786: float (nullable = true)
#  |-- component_787: float (nullable = true)
#  |-- component_788: float (nullable = true)
#  |-- component_789: float (nullable = true)
#  |-- component_790: float (nullable = true)
#  |-- component_791: float (nullable = true)
#  |-- component_792: float (nullable = true)
#  |-- component_793: float (nullable = true)
#  |-- component_794: float (nullable = true)
#  |-- component_795: float (nullable = true)
#  |-- component_796: float (nullable = true)
#  |-- component_797: float (nullable = true)
#  |-- component_798: float (nullable = true)
#  |-- component_799: float (nullable = true)
#  |-- component_800: float (nullable = true)
#  |-- component_801: float (nullable = true)
#  |-- component_802: float (nullable = true)
#  |-- component_803: float (nullable = true)
#  |-- component_804: float (nullable = true)
#  |-- component_805: float (nullable = true)
#  |-- component_806: float (nullable = true)
#  |-- component_807: float (nullable = true)
#  |-- component_808: float (nullable = true)
#  |-- component_809: float (nullable = true)
#  |-- component_810: float (nullable = true)
#  |-- component_811: float (nullable = true)
#  |-- component_812: float (nullable = true)
#  |-- component_813: float (nullable = true)
#  |-- component_814: float (nullable = true)
#  |-- component_815: float (nullable = true)
#  |-- component_816: float (nullable = true)
#  |-- component_817: float (nullable = true)
#  |-- component_818: float (nullable = true)
#  |-- component_819: float (nullable = true)
#  |-- component_820: float (nullable = true)
#  |-- component_821: float (nullable = true)
#  |-- component_822: float (nullable = true)
#  |-- component_823: float (nullable = true)
#  |-- component_824: float (nullable = true)
#  |-- component_825: float (nullable = true)
#  |-- component_826: float (nullable = true)
#  |-- component_827: float (nullable = true)
#  |-- component_828: float (nullable = true)
#  |-- component_829: float (nullable = true)
#  |-- component_830: float (nullable = true)
#  |-- component_831: float (nullable = true)
#  |-- component_832: float (nullable = true)
#  |-- component_833: float (nullable = true)
#  |-- component_834: float (nullable = true)
#  |-- component_835: float (nullable = true)
#  |-- component_836: float (nullable = true)
#  |-- component_837: float (nullable = true)
#  |-- component_838: float (nullable = true)
#  |-- component_839: float (nullable = true)
#  |-- component_840: float (nullable = true)
#  |-- component_841: float (nullable = true)
#  |-- component_842: float (nullable = true)
#  |-- component_843: float (nullable = true)
#  |-- component_844: float (nullable = true)
#  |-- component_845: float (nullable = true)
#  |-- component_846: float (nullable = true)
#  |-- component_847: float (nullable = true)
#  |-- component_848: float (nullable = true)
#  |-- component_849: float (nullable = true)
#  |-- component_850: float (nullable = true)
#  |-- component_851: float (nullable = true)
#  |-- component_852: float (nullable = true)
#  |-- component_853: float (nullable = true)
#  |-- component_854: float (nullable = true)
#  |-- component_855: float (nullable = true)
#  |-- component_856: float (nullable = true)
#  |-- component_857: float (nullable = true)
#  |-- component_858: float (nullable = true)
#  |-- component_859: float (nullable = true)
#  |-- component_860: float (nullable = true)
#  |-- component_861: float (nullable = true)
#  |-- component_862: float (nullable = true)
#  |-- component_863: float (nullable = true)
#  |-- component_864: float (nullable = true)
#  |-- component_865: float (nullable = true)
#  |-- component_866: float (nullable = true)
#  |-- component_867: float (nullable = true)
#  |-- component_868: float (nullable = true)
#  |-- component_869: float (nullable = true)
#  |-- component_870: float (nullable = true)
#  |-- component_871: float (nullable = true)
#  |-- component_872: float (nullable = true)
#  |-- component_873: float (nullable = true)
#  |-- component_874: float (nullable = true)
#  |-- component_875: float (nullable = true)
#  |-- component_876: float (nullable = true)
#  |-- component_877: float (nullable = true)
#  |-- component_878: float (nullable = true)
#  |-- component_879: float (nullable = true)
#  |-- component_880: float (nullable = true)
#  |-- component_881: float (nullable = true)
#  |-- component_882: float (nullable = true)
#  |-- component_883: float (nullable = true)
#  |-- component_884: float (nullable = true)
#  |-- component_885: float (nullable = true)
#  |-- component_886: float (nullable = true)
#  |-- component_887: float (nullable = true)
#  |-- component_888: float (nullable = true)
#  |-- component_889: float (nullable = true)
#  |-- component_890: float (nullable = true)
#  |-- component_891: float (nullable = true)
#  |-- component_892: float (nullable = true)
#  |-- component_893: float (nullable = true)
#  |-- component_894: float (nullable = true)
#  |-- component_895: float (nullable = true)
#  |-- component_896: float (nullable = true)
#  |-- component_897: float (nullable = true)
#  |-- component_898: float (nullable = true)
#  |-- component_899: float (nullable = true)
#  |-- component_900: float (nullable = true)
#  |-- component_901: float (nullable = true)
#  |-- component_902: float (nullable = true)
#  |-- component_903: float (nullable = true)
#  |-- component_904: float (nullable = true)
#  |-- component_905: float (nullable = true)
#  |-- component_906: float (nullable = true)
#  |-- component_907: float (nullable = true)
#  |-- component_908: float (nullable = true)
#  |-- component_909: float (nullable = true)
#  |-- component_910: float (nullable = true)
#  |-- component_911: float (nullable = true)
#  |-- component_912: float (nullable = true)
#  |-- component_913: float (nullable = true)
#  |-- component_914: float (nullable = true)
#  |-- component_915: float (nullable = true)
#  |-- component_916: float (nullable = true)
#  |-- component_917: float (nullable = true)
#  |-- component_918: float (nullable = true)
#  |-- component_919: float (nullable = true)
#  |-- component_920: float (nullable = true)
#  |-- component_921: float (nullable = true)
#  |-- component_922: float (nullable = true)
#  |-- component_923: float (nullable = true)
#  |-- component_924: float (nullable = true)
#  |-- component_925: float (nullable = true)
#  |-- component_926: float (nullable = true)
#  |-- component_927: float (nullable = true)
#  |-- component_928: float (nullable = true)
#  |-- component_929: float (nullable = true)
#  |-- component_930: float (nullable = true)
#  |-- component_931: float (nullable = true)
#  |-- component_932: float (nullable = true)
#  |-- component_933: float (nullable = true)
#  |-- component_934: float (nullable = true)
#  |-- component_935: float (nullable = true)
#  |-- component_936: float (nullable = true)
#  |-- component_937: float (nullable = true)
#  |-- component_938: float (nullable = true)
#  |-- component_939: float (nullable = true)
#  |-- component_940: float (nullable = true)
#  |-- component_941: float (nullable = true)
#  |-- component_942: float (nullable = true)
#  |-- component_943: float (nullable = true)
#  |-- component_944: float (nullable = true)
#  |-- component_945: float (nullable = true)
#  |-- component_946: float (nullable = true)
#  |-- component_947: float (nullable = true)
#  |-- component_948: float (nullable = true)
#  |-- component_949: float (nullable = true)
#  |-- component_950: float (nullable = true)
#  |-- component_951: float (nullable = true)
#  |-- component_952: float (nullable = true)
#  |-- component_953: float (nullable = true)
#  |-- component_954: float (nullable = true)
#  |-- component_955: float (nullable = true)
#  |-- component_956: float (nullable = true)
#  |-- component_957: float (nullable = true)
#  |-- component_958: float (nullable = true)
#  |-- component_959: float (nullable = true)
#  |-- component_960: float (nullable = true)
#  |-- component_961: float (nullable = true)
#  |-- component_962: float (nullable = true)
#  |-- component_963: float (nullable = true)
#  |-- component_964: float (nullable = true)
#  |-- component_965: float (nullable = true)
#  |-- component_966: float (nullable = true)
#  |-- component_967: float (nullable = true)
#  |-- component_968: float (nullable = true)
#  |-- component_969: float (nullable = true)
#  |-- component_970: float (nullable = true)
#  |-- component_971: float (nullable = true)
#  |-- component_972: float (nullable = true)
#  |-- component_973: float (nullable = true)
#  |-- component_974: float (nullable = true)
#  |-- component_975: float (nullable = true)
#  |-- component_976: float (nullable = true)
#  |-- component_977: float (nullable = true)
#  |-- component_978: float (nullable = true)
#  |-- component_979: float (nullable = true)
#  |-- component_980: float (nullable = true)
#  |-- component_981: float (nullable = true)
#  |-- component_982: float (nullable = true)
#  |-- component_983: float (nullable = true)
#  |-- component_984: float (nullable = true)
#  |-- component_985: float (nullable = true)
#  |-- component_986: float (nullable = true)
#  |-- component_987: float (nullable = true)
#  |-- component_988: float (nullable = true)
#  |-- component_989: float (nullable = true)
#  |-- component_990: float (nullable = true)
#  |-- component_991: float (nullable = true)
#  |-- component_992: float (nullable = true)
#  |-- component_993: float (nullable = true)
#  |-- component_994: float (nullable = true)
#  |-- component_995: float (nullable = true)
#  |-- component_996: float (nullable = true)
#  |-- component_997: float (nullable = true)
#  |-- component_998: float (nullable = true)
#  |-- component_999: float (nullable = true)
#  |-- component_1000: float (nullable = true)
#  |-- component_1001: float (nullable = true)
#  |-- component_1002: float (nullable = true)
#  |-- component_1003: float (nullable = true)
#  |-- component_1004: float (nullable = true)
#  |-- component_1005: float (nullable = true)
#  |-- component_1006: float (nullable = true)
#  |-- component_1007: float (nullable = true)
#  |-- component_1008: float (nullable = true)
#  |-- component_1009: float (nullable = true)
#  |-- component_1010: float (nullable = true)
#  |-- component_1011: float (nullable = true)
#  |-- component_1012: float (nullable = true)
#  |-- component_1013: float (nullable = true)
#  |-- component_1014: float (nullable = true)
#  |-- component_1015: float (nullable = true)
#  |-- component_1016: float (nullable = true)
#  |-- component_1017: float (nullable = true)
#  |-- component_1018: float (nullable = true)
#  |-- component_1019: float (nullable = true)
#  |-- component_1020: float (nullable = true)
#  |-- component_1021: float (nullable = true)
#  |-- component_1022: float (nullable = true)
#  |-- component_1023: float (nullable = true)
#  |-- component_1024: float (nullable = true)
#  |-- component_1025: float (nullable = true)
#  |-- component_1026: float (nullable = true)
#  |-- component_1027: float (nullable = true)
#  |-- component_1028: float (nullable = true)
#  |-- component_1029: float (nullable = true)
#  |-- component_1030: float (nullable = true)
#  |-- component_1031: float (nullable = true)
#  |-- component_1032: float (nullable = true)
#  |-- component_1033: float (nullable = true)
#  |-- component_1034: float (nullable = true)
#  |-- component_1035: float (nullable = true)
#  |-- component_1036: float (nullable = true)
#  |-- component_1037: float (nullable = true)
#  |-- component_1038: float (nullable = true)
#  |-- component_1039: float (nullable = true)
#  |-- component_1040: float (nullable = true)
#  |-- component_1041: float (nullable = true)
#  |-- component_1042: float (nullable = true)
#  |-- component_1043: float (nullable = true)
#  |-- component_1044: float (nullable = true)
#  |-- component_1045: float (nullable = true)
#  |-- component_1046: float (nullable = true)
#  |-- component_1047: float (nullable = true)
#  |-- component_1048: float (nullable = true)
#  |-- component_1049: float (nullable = true)
#  |-- component_1050: float (nullable = true)
#  |-- component_1051: float (nullable = true)
#  |-- component_1052: float (nullable = true)
#  |-- component_1053: float (nullable = true)
#  |-- component_1054: float (nullable = true)
#  |-- component_1055: float (nullable = true)
#  |-- component_1056: float (nullable = true)
#  |-- component_1057: float (nullable = true)
#  |-- component_1058: float (nullable = true)
#  |-- component_1059: float (nullable = true)
#  |-- component_1060: float (nullable = true)
#  |-- component_1061: float (nullable = true)
#  |-- component_1062: float (nullable = true)
#  |-- component_1063: float (nullable = true)
#  |-- component_1064: float (nullable = true)
#  |-- component_1065: float (nullable = true)
#  |-- component_1066: float (nullable = true)
#  |-- component_1067: float (nullable = true)
#  |-- component_1068: float (nullable = true)
#  |-- component_1069: float (nullable = true)
#  |-- component_1070: float (nullable = true)
#  |-- component_1071: float (nullable = true)
#  |-- component_1072: float (nullable = true)
#  |-- component_1073: float (nullable = true)
#  |-- component_1074: float (nullable = true)
#  |-- component_1075: float (nullable = true)
#  |-- component_1076: float (nullable = true)
#  |-- component_1077: float (nullable = true)
#  |-- component_1078: float (nullable = true)
#  |-- component_1079: float (nullable = true)
#  |-- component_1080: float (nullable = true)
#  |-- component_1081: float (nullable = true)
#  |-- component_1082: float (nullable = true)
#  |-- component_1083: float (nullable = true)
#  |-- component_1084: float (nullable = true)
#  |-- component_1085: float (nullable = true)
#  |-- component_1086: float (nullable = true)
#  |-- component_1087: float (nullable = true)
#  |-- component_1088: float (nullable = true)
#  |-- component_1089: float (nullable = true)
#  |-- component_1090: float (nullable = true)
#  |-- component_1091: float (nullable = true)
#  |-- component_1092: float (nullable = true)
#  |-- component_1093: float (nullable = true)
#  |-- component_1094: float (nullable = true)
#  |-- component_1095: float (nullable = true)
#  |-- component_1096: float (nullable = true)
#  |-- component_1097: float (nullable = true)
#  |-- component_1098: float (nullable = true)
#  |-- component_1099: float (nullable = true)
#  |-- component_1100: float (nullable = true)
#  |-- component_1101: float (nullable = true)
#  |-- component_1102: float (nullable = true)
#  |-- component_1103: float (nullable = true)
#  |-- component_1104: float (nullable = true)
#  |-- component_1105: float (nullable = true)
#  |-- component_1106: float (nullable = true)
#  |-- component_1107: float (nullable = true)
#  |-- component_1108: float (nullable = true)
#  |-- component_1109: float (nullable = true)
#  |-- component_1110: float (nullable = true)
#  |-- component_1111: float (nullable = true)
#  |-- component_1112: float (nullable = true)
#  |-- component_1113: float (nullable = true)
#  |-- component_1114: float (nullable = true)
#  |-- component_1115: float (nullable = true)
#  |-- component_1116: float (nullable = true)
#  |-- component_1117: float (nullable = true)
#  |-- component_1118: float (nullable = true)
#  |-- component_1119: float (nullable = true)
#  |-- component_1120: float (nullable = true)
#  |-- component_1121: float (nullable = true)
#  |-- component_1122: float (nullable = true)
#  |-- component_1123: float (nullable = true)
#  |-- component_1124: float (nullable = true)
#  |-- component_1125: float (nullable = true)
#  |-- component_1126: float (nullable = true)
#  |-- component_1127: float (nullable = true)
#  |-- component_1128: float (nullable = true)
#  |-- component_1129: float (nullable = true)
#  |-- component_1130: float (nullable = true)
#  |-- component_1131: float (nullable = true)
#  |-- component_1132: float (nullable = true)
#  |-- component_1133: float (nullable = true)
#  |-- component_1134: float (nullable = true)
#  |-- component_1135: float (nullable = true)
#  |-- component_1136: float (nullable = true)
#  |-- component_1137: float (nullable = true)
#  |-- component_1138: float (nullable = true)
#  |-- component_1139: float (nullable = true)
#  |-- component_1140: float (nullable = true)
#  |-- component_1141: float (nullable = true)
#  |-- component_1142: float (nullable = true)
#  |-- component_1143: float (nullable = true)
#  |-- component_1144: float (nullable = true)
#  |-- component_1145: float (nullable = true)
#  |-- component_1146: float (nullable = true)
#  |-- component_1147: float (nullable = true)
#  |-- component_1148: float (nullable = true)
#  |-- component_1149: float (nullable = true)
#  |-- component_1150: float (nullable = true)
#  |-- component_1151: float (nullable = true)
#  |-- component_1152: float (nullable = true)
#  |-- component_1153: float (nullable = true)
#  |-- component_1154: float (nullable = true)
#  |-- component_1155: float (nullable = true)
#  |-- component_1156: float (nullable = true)
#  |-- component_1157: float (nullable = true)
#  |-- component_1158: float (nullable = true)
#  |-- component_1159: float (nullable = true)
#  |-- component_1160: float (nullable = true)
#  |-- component_1161: float (nullable = true)
#  |-- component_1162: float (nullable = true)
#  |-- component_1163: float (nullable = true)
#  |-- component_1164: float (nullable = true)
#  |-- component_1165: float (nullable = true)
#  |-- component_1166: float (nullable = true)
#  |-- component_1167: float (nullable = true)
#  |-- component_1168: float (nullable = true)
#  |-- component_1169: float (nullable = true)
#  |-- component_1170: float (nullable = true)
#  |-- component_1171: float (nullable = true)
#  |-- component_1172: float (nullable = true)
#  |-- component_1173: float (nullable = true)
#  |-- component_1174: float (nullable = true)
#  |-- component_1175: float (nullable = true)
#  |-- component_1176: float (nullable = true)
#  |-- component_1177: float (nullable = true)
#  |-- component_1178: float (nullable = true)
#  |-- component_1179: float (nullable = true)
#  |-- component_1180: float (nullable = true)
#  |-- component_1181: float (nullable = true)
#  |-- component_1182: float (nullable = true)
#  |-- component_1183: float (nullable = true)
#  |-- component_1184: float (nullable = true)
#  |-- component_1185: float (nullable = true)
#  |-- component_1186: float (nullable = true)
#  |-- component_1187: float (nullable = true)
#  |-- component_1188: float (nullable = true)
#  |-- component_1189: float (nullable = true)
#  |-- component_1190: float (nullable = true)
#  |-- component_1191: float (nullable = true)
#  |-- component_1192: float (nullable = true)
#  |-- component_1193: float (nullable = true)
#  |-- component_1194: float (nullable = true)
#  |-- component_1195: float (nullable = true)
#  |-- component_1196: float (nullable = true)
#  |-- component_1197: float (nullable = true)
#  |-- component_1198: float (nullable = true)
#  |-- component_1199: float (nullable = true)
#  |-- component_1200: float (nullable = true)
#  |-- component_1201: float (nullable = true)
#  |-- component_1202: float (nullable = true)
#  |-- component_1203: float (nullable = true)
#  |-- component_1204: float (nullable = true)
#  |-- component_1205: float (nullable = true)
#  |-- component_1206: float (nullable = true)
#  |-- component_1207: float (nullable = true)
#  |-- component_1208: float (nullable = true)
#  |-- component_1209: float (nullable = true)
#  |-- component_1210: float (nullable = true)
#  |-- component_1211: float (nullable = true)
#  |-- component_1212: float (nullable = true)
#  |-- component_1213: float (nullable = true)
#  |-- component_1214: float (nullable = true)
#  |-- component_1215: float (nullable = true)
#  |-- component_1216: float (nullable = true)
#  |-- component_1217: float (nullable = true)
#  |-- component_1218: float (nullable = true)
#  |-- component_1219: float (nullable = true)
#  |-- component_1220: float (nullable = true)
#  |-- component_1221: float (nullable = true)
#  |-- component_1222: float (nullable = true)
#  |-- component_1223: float (nullable = true)
#  |-- component_1224: float (nullable = true)
#  |-- component_1225: float (nullable = true)
#  |-- component_1226: float (nullable = true)
#  |-- component_1227: float (nullable = true)
#  |-- component_1228: float (nullable = true)
#  |-- component_1229: float (nullable = true)
#  |-- component_1230: float (nullable = true)
#  |-- component_1231: float (nullable = true)
#  |-- component_1232: float (nullable = true)
#  |-- component_1233: float (nullable = true)
#  |-- component_1234: float (nullable = true)
#  |-- component_1235: float (nullable = true)
#  |-- component_1236: float (nullable = true)
#  |-- component_1237: float (nullable = true)
#  |-- component_1238: float (nullable = true)
#  |-- component_1239: float (nullable = true)
#  |-- component_1240: float (nullable = true)
#  |-- component_1241: float (nullable = true)
#  |-- component_1242: float (nullable = true)
#  |-- component_1243: float (nullable = true)
#  |-- component_1244: float (nullable = true)
#  |-- component_1245: float (nullable = true)
#  |-- component_1246: float (nullable = true)
#  |-- component_1247: float (nullable = true)
#  |-- component_1248: float (nullable = true)
#  |-- component_1249: float (nullable = true)
#  |-- component_1250: float (nullable = true)
#  |-- component_1251: float (nullable = true)
#  |-- component_1252: float (nullable = true)
#  |-- component_1253: float (nullable = true)
#  |-- component_1254: float (nullable = true)
#  |-- component_1255: float (nullable = true)
#  |-- component_1256: float (nullable = true)
#  |-- component_1257: float (nullable = true)
#  |-- component_1258: float (nullable = true)
#  |-- component_1259: float (nullable = true)
#  |-- component_1260: float (nullable = true)
#  |-- component_1261: float (nullable = true)
#  |-- component_1262: float (nullable = true)
#  |-- component_1263: float (nullable = true)
#  |-- component_1264: float (nullable = true)
#  |-- component_1265: float (nullable = true)
#  |-- component_1266: float (nullable = true)
#  |-- component_1267: float (nullable = true)
#  |-- component_1268: float (nullable = true)
#  |-- component_1269: float (nullable = true)
#  |-- component_1270: float (nullable = true)
#  |-- component_1271: float (nullable = true)
#  |-- component_1272: float (nullable = true)
#  |-- component_1273: float (nullable = true)
#  |-- component_1274: float (nullable = true)
#  |-- component_1275: float (nullable = true)
#  |-- component_1276: float (nullable = true)
#  |-- component_1277: float (nullable = true)
#  |-- component_1278: float (nullable = true)
#  |-- component_1279: float (nullable = true)
#  |-- component_1280: float (nullable = true)

# %%
# Colonne à enregistrer : 
selected_columns = ["path", "label"] + [f"feature_{i+1}" for i in range(num_features)]
df_selected = df.select(*selected_columns)

# %%
df_selected.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- component_1: float (nullable = true)
#  |-- component_2: float (nullable = true)
#  |-- component_3: float (nullable = true)
#  |-- component_4: float (nullable = true)
#  |-- component_5: float (nullable = true)
#  |-- component_6: float (nullable = true)
#  |-- component_7: float (nullable = true)
#  |-- component_8: float (nullable = true)
#  |-- component_9: float (nullable = true)
#  |-- component_10: float (nullable = true)
#  |-- component_11: float (nullable = true)
#  |-- component_12: float (nullable = true)
#  |-- component_13: float (nullable = true)
#  |-- component_14: float (nullable = true)
#  |-- component_15: float (nullable = true)
#  |-- component_16: float (nullable = true)
#  |-- component_17: float (nullable = true)
#  |-- component_18: float (nullable = true)
#  |-- component_19: float (nullable = true)
#  |-- component_20: float (nullable = true)
#  |-- component_21: float (nullable = true)
#  |-- component_22: float (nullable = true)
#  |-- component_23: float (nullable = true)
#  |-- component_24: float (nullable = true)
#  |-- component_25: float (nullable = true)
#  |-- component_26: float (nullable = true)
#  |-- component_27: float (nullable = true)
#  |-- component_28: float (nullable = true)
#  |-- component_29: float (nullable = true)
#  |-- component_30: float (nullable = true)
#  |-- component_31: float (nullable = true)
#  |-- component_32: float (nullable = true)
#  |-- component_33: float (nullable = true)
#  |-- component_34: float (nullable = true)
#  |-- component_35: float (nullable = true)
#  |-- component_36: float (nullable = true)
#  |-- component_37: float (nullable = true)
#  |-- component_38: float (nullable = true)
#  |-- component_39: float (nullable = true)
#  |-- component_40: float (nullable = true)
#  |-- component_41: float (nullable = true)
#  |-- component_42: float (nullable = true)
#  |-- component_43: float (nullable = true)
#  |-- component_44: float (nullable = true)
#  |-- component_45: float (nullable = true)
#  |-- component_46: float (nullable = true)
#  |-- component_47: float (nullable = true)
#  |-- component_48: float (nullable = true)
#  |-- component_49: float (nullable = true)
#  |-- component_50: float (nullable = true)
#  |-- component_51: float (nullable = true)
#  |-- component_52: float (nullable = true)
#  |-- component_53: float (nullable = true)
#  |-- component_54: float (nullable = true)
#  |-- component_55: float (nullable = true)
#  |-- component_56: float (nullable = true)
#  |-- component_57: float (nullable = true)
#  |-- component_58: float (nullable = true)
#  |-- component_59: float (nullable = true)
#  |-- component_60: float (nullable = true)
#  |-- component_61: float (nullable = true)
#  |-- component_62: float (nullable = true)
#  |-- component_63: float (nullable = true)
#  |-- component_64: float (nullable = true)
#  |-- component_65: float (nullable = true)
#  |-- component_66: float (nullable = true)
#  |-- component_67: float (nullable = true)
#  |-- component_68: float (nullable = true)
#  |-- component_69: float (nullable = true)
#  |-- component_70: float (nullable = true)
#  |-- component_71: float (nullable = true)
#  |-- component_72: float (nullable = true)
#  |-- component_73: float (nullable = true)
#  |-- component_74: float (nullable = true)
#  |-- component_75: float (nullable = true)
#  |-- component_76: float (nullable = true)
#  |-- component_77: float (nullable = true)
#  |-- component_78: float (nullable = true)
#  |-- component_79: float (nullable = true)
#  |-- component_80: float (nullable = true)
#  |-- component_81: float (nullable = true)
#  |-- component_82: float (nullable = true)
#  |-- component_83: float (nullable = true)
#  |-- component_84: float (nullable = true)
#  |-- component_85: float (nullable = true)
#  |-- component_86: float (nullable = true)
#  |-- component_87: float (nullable = true)
#  |-- component_88: float (nullable = true)
#  |-- component_89: float (nullable = true)
#  |-- component_90: float (nullable = true)
#  |-- component_91: float (nullable = true)
#  |-- component_92: float (nullable = true)
#  |-- component_93: float (nullable = true)
#  |-- component_94: float (nullable = true)
#  |-- component_95: float (nullable = true)
#  |-- component_96: float (nullable = true)
#  |-- component_97: float (nullable = true)
#  |-- component_98: float (nullable = true)
#  |-- component_99: float (nullable = true)
#  |-- component_100: float (nullable = true)
#  |-- component_101: float (nullable = true)
#  |-- component_102: float (nullable = true)
#  |-- component_103: float (nullable = true)
#  |-- component_104: float (nullable = true)
#  |-- component_105: float (nullable = true)
#  |-- component_106: float (nullable = true)
#  |-- component_107: float (nullable = true)
#  |-- component_108: float (nullable = true)
#  |-- component_109: float (nullable = true)
#  |-- component_110: float (nullable = true)
#  |-- component_111: float (nullable = true)
#  |-- component_112: float (nullable = true)
#  |-- component_113: float (nullable = true)
#  |-- component_114: float (nullable = true)
#  |-- component_115: float (nullable = true)
#  |-- component_116: float (nullable = true)
#  |-- component_117: float (nullable = true)
#  |-- component_118: float (nullable = true)
#  |-- component_119: float (nullable = true)
#  |-- component_120: float (nullable = true)
#  |-- component_121: float (nullable = true)
#  |-- component_122: float (nullable = true)
#  |-- component_123: float (nullable = true)
#  |-- component_124: float (nullable = true)
#  |-- component_125: float (nullable = true)
#  |-- component_126: float (nullable = true)
#  |-- component_127: float (nullable = true)
#  |-- component_128: float (nullable = true)
#  |-- component_129: float (nullable = true)
#  |-- component_130: float (nullable = true)
#  |-- component_131: float (nullable = true)
#  |-- component_132: float (nullable = true)
#  |-- component_133: float (nullable = true)
#  |-- component_134: float (nullable = true)
#  |-- component_135: float (nullable = true)
#  |-- component_136: float (nullable = true)
#  |-- component_137: float (nullable = true)
#  |-- component_138: float (nullable = true)
#  |-- component_139: float (nullable = true)
#  |-- component_140: float (nullable = true)
#  |-- component_141: float (nullable = true)
#  |-- component_142: float (nullable = true)
#  |-- component_143: float (nullable = true)
#  |-- component_144: float (nullable = true)
#  |-- component_145: float (nullable = true)
#  |-- component_146: float (nullable = true)
#  |-- component_147: float (nullable = true)
#  |-- component_148: float (nullable = true)
#  |-- component_149: float (nullable = true)
#  |-- component_150: float (nullable = true)
#  |-- component_151: float (nullable = true)
#  |-- component_152: float (nullable = true)
#  |-- component_153: float (nullable = true)
#  |-- component_154: float (nullable = true)
#  |-- component_155: float (nullable = true)
#  |-- component_156: float (nullable = true)
#  |-- component_157: float (nullable = true)
#  |-- component_158: float (nullable = true)
#  |-- component_159: float (nullable = true)
#  |-- component_160: float (nullable = true)
#  |-- component_161: float (nullable = true)
#  |-- component_162: float (nullable = true)
#  |-- component_163: float (nullable = true)
#  |-- component_164: float (nullable = true)
#  |-- component_165: float (nullable = true)
#  |-- component_166: float (nullable = true)
#  |-- component_167: float (nullable = true)
#  |-- component_168: float (nullable = true)
#  |-- component_169: float (nullable = true)
#  |-- component_170: float (nullable = true)
#  |-- component_171: float (nullable = true)
#  |-- component_172: float (nullable = true)
#  |-- component_173: float (nullable = true)
#  |-- component_174: float (nullable = true)
#  |-- component_175: float (nullable = true)
#  |-- component_176: float (nullable = true)
#  |-- component_177: float (nullable = true)
#  |-- component_178: float (nullable = true)
#  |-- component_179: float (nullable = true)
#  |-- component_180: float (nullable = true)
#  |-- component_181: float (nullable = true)
#  |-- component_182: float (nullable = true)
#  |-- component_183: float (nullable = true)
#  |-- component_184: float (nullable = true)
#  |-- component_185: float (nullable = true)
#  |-- component_186: float (nullable = true)
#  |-- component_187: float (nullable = true)
#  |-- component_188: float (nullable = true)
#  |-- component_189: float (nullable = true)
#  |-- component_190: float (nullable = true)
#  |-- component_191: float (nullable = true)
#  |-- component_192: float (nullable = true)
#  |-- component_193: float (nullable = true)
#  |-- component_194: float (nullable = true)
#  |-- component_195: float (nullable = true)
#  |-- component_196: float (nullable = true)
#  |-- component_197: float (nullable = true)
#  |-- component_198: float (nullable = true)
#  |-- component_199: float (nullable = true)
#  |-- component_200: float (nullable = true)
#  |-- component_201: float (nullable = true)
#  |-- component_202: float (nullable = true)
#  |-- component_203: float (nullable = true)
#  |-- component_204: float (nullable = true)
#  |-- component_205: float (nullable = true)
#  |-- component_206: float (nullable = true)
#  |-- component_207: float (nullable = true)
#  |-- component_208: float (nullable = true)
#  |-- component_209: float (nullable = true)
#  |-- component_210: float (nullable = true)
#  |-- component_211: float (nullable = true)
#  |-- component_212: float (nullable = true)
#  |-- component_213: float (nullable = true)
#  |-- component_214: float (nullable = true)
#  |-- component_215: float (nullable = true)
#  |-- component_216: float (nullable = true)
#  |-- component_217: float (nullable = true)
#  |-- component_218: float (nullable = true)
#  |-- component_219: float (nullable = true)
#  |-- component_220: float (nullable = true)
#  |-- component_221: float (nullable = true)
#  |-- component_222: float (nullable = true)
#  |-- component_223: float (nullable = true)
#  |-- component_224: float (nullable = true)
#  |-- component_225: float (nullable = true)
#  |-- component_226: float (nullable = true)
#  |-- component_227: float (nullable = true)
#  |-- component_228: float (nullable = true)
#  |-- component_229: float (nullable = true)
#  |-- component_230: float (nullable = true)
#  |-- component_231: float (nullable = true)
#  |-- component_232: float (nullable = true)
#  |-- component_233: float (nullable = true)
#  |-- component_234: float (nullable = true)
#  |-- component_235: float (nullable = true)
#  |-- component_236: float (nullable = true)
#  |-- component_237: float (nullable = true)
#  |-- component_238: float (nullable = true)
#  |-- component_239: float (nullable = true)
#  |-- component_240: float (nullable = true)
#  |-- component_241: float (nullable = true)
#  |-- component_242: float (nullable = true)
#  |-- component_243: float (nullable = true)
#  |-- component_244: float (nullable = true)
#  |-- component_245: float (nullable = true)
#  |-- component_246: float (nullable = true)
#  |-- component_247: float (nullable = true)
#  |-- component_248: float (nullable = true)
#  |-- component_249: float (nullable = true)
#  |-- component_250: float (nullable = true)
#  |-- component_251: float (nullable = true)
#  |-- component_252: float (nullable = true)
#  |-- component_253: float (nullable = true)
#  |-- component_254: float (nullable = true)
#  |-- component_255: float (nullable = true)
#  |-- component_256: float (nullable = true)
#  |-- component_257: float (nullable = true)
#  |-- component_258: float (nullable = true)
#  |-- component_259: float (nullable = true)
#  |-- component_260: float (nullable = true)
#  |-- component_261: float (nullable = true)
#  |-- component_262: float (nullable = true)
#  |-- component_263: float (nullable = true)
#  |-- component_264: float (nullable = true)
#  |-- component_265: float (nullable = true)
#  |-- component_266: float (nullable = true)
#  |-- component_267: float (nullable = true)
#  |-- component_268: float (nullable = true)
#  |-- component_269: float (nullable = true)
#  |-- component_270: float (nullable = true)
#  |-- component_271: float (nullable = true)
#  |-- component_272: float (nullable = true)
#  |-- component_273: float (nullable = true)
#  |-- component_274: float (nullable = true)
#  |-- component_275: float (nullable = true)
#  |-- component_276: float (nullable = true)
#  |-- component_277: float (nullable = true)
#  |-- component_278: float (nullable = true)
#  |-- component_279: float (nullable = true)
#  |-- component_280: float (nullable = true)
#  |-- component_281: float (nullable = true)
#  |-- component_282: float (nullable = true)
#  |-- component_283: float (nullable = true)
#  |-- component_284: float (nullable = true)
#  |-- component_285: float (nullable = true)
#  |-- component_286: float (nullable = true)
#  |-- component_287: float (nullable = true)
#  |-- component_288: float (nullable = true)
#  |-- component_289: float (nullable = true)
#  |-- component_290: float (nullable = true)
#  |-- component_291: float (nullable = true)
#  |-- component_292: float (nullable = true)
#  |-- component_293: float (nullable = true)
#  |-- component_294: float (nullable = true)
#  |-- component_295: float (nullable = true)
#  |-- component_296: float (nullable = true)
#  |-- component_297: float (nullable = true)
#  |-- component_298: float (nullable = true)
#  |-- component_299: float (nullable = true)
#  |-- component_300: float (nullable = true)
#  |-- component_301: float (nullable = true)
#  |-- component_302: float (nullable = true)
#  |-- component_303: float (nullable = true)
#  |-- component_304: float (nullable = true)
#  |-- component_305: float (nullable = true)
#  |-- component_306: float (nullable = true)
#  |-- component_307: float (nullable = true)
#  |-- component_308: float (nullable = true)
#  |-- component_309: float (nullable = true)
#  |-- component_310: float (nullable = true)
#  |-- component_311: float (nullable = true)
#  |-- component_312: float (nullable = true)
#  |-- component_313: float (nullable = true)
#  |-- component_314: float (nullable = true)
#  |-- component_315: float (nullable = true)
#  |-- component_316: float (nullable = true)
#  |-- component_317: float (nullable = true)
#  |-- component_318: float (nullable = true)
#  |-- component_319: float (nullable = true)
#  |-- component_320: float (nullable = true)
#  |-- component_321: float (nullable = true)
#  |-- component_322: float (nullable = true)
#  |-- component_323: float (nullable = true)
#  |-- component_324: float (nullable = true)
#  |-- component_325: float (nullable = true)
#  |-- component_326: float (nullable = true)
#  |-- component_327: float (nullable = true)
#  |-- component_328: float (nullable = true)
#  |-- component_329: float (nullable = true)
#  |-- component_330: float (nullable = true)
#  |-- component_331: float (nullable = true)
#  |-- component_332: float (nullable = true)
#  |-- component_333: float (nullable = true)
#  |-- component_334: float (nullable = true)
#  |-- component_335: float (nullable = true)
#  |-- component_336: float (nullable = true)
#  |-- component_337: float (nullable = true)
#  |-- component_338: float (nullable = true)
#  |-- component_339: float (nullable = true)
#  |-- component_340: float (nullable = true)
#  |-- component_341: float (nullable = true)
#  |-- component_342: float (nullable = true)
#  |-- component_343: float (nullable = true)
#  |-- component_344: float (nullable = true)
#  |-- component_345: float (nullable = true)
#  |-- component_346: float (nullable = true)
#  |-- component_347: float (nullable = true)
#  |-- component_348: float (nullable = true)
#  |-- component_349: float (nullable = true)
#  |-- component_350: float (nullable = true)
#  |-- component_351: float (nullable = true)
#  |-- component_352: float (nullable = true)
#  |-- component_353: float (nullable = true)
#  |-- component_354: float (nullable = true)
#  |-- component_355: float (nullable = true)
#  |-- component_356: float (nullable = true)
#  |-- component_357: float (nullable = true)
#  |-- component_358: float (nullable = true)
#  |-- component_359: float (nullable = true)
#  |-- component_360: float (nullable = true)
#  |-- component_361: float (nullable = true)
#  |-- component_362: float (nullable = true)
#  |-- component_363: float (nullable = true)
#  |-- component_364: float (nullable = true)
#  |-- component_365: float (nullable = true)
#  |-- component_366: float (nullable = true)
#  |-- component_367: float (nullable = true)
#  |-- component_368: float (nullable = true)
#  |-- component_369: float (nullable = true)
#  |-- component_370: float (nullable = true)
#  |-- component_371: float (nullable = true)
#  |-- component_372: float (nullable = true)
#  |-- component_373: float (nullable = true)
#  |-- component_374: float (nullable = true)
#  |-- component_375: float (nullable = true)
#  |-- component_376: float (nullable = true)
#  |-- component_377: float (nullable = true)
#  |-- component_378: float (nullable = true)
#  |-- component_379: float (nullable = true)
#  |-- component_380: float (nullable = true)
#  |-- component_381: float (nullable = true)
#  |-- component_382: float (nullable = true)
#  |-- component_383: float (nullable = true)
#  |-- component_384: float (nullable = true)
#  |-- component_385: float (nullable = true)
#  |-- component_386: float (nullable = true)
#  |-- component_387: float (nullable = true)
#  |-- component_388: float (nullable = true)
#  |-- component_389: float (nullable = true)
#  |-- component_390: float (nullable = true)
#  |-- component_391: float (nullable = true)
#  |-- component_392: float (nullable = true)
#  |-- component_393: float (nullable = true)
#  |-- component_394: float (nullable = true)
#  |-- component_395: float (nullable = true)
#  |-- component_396: float (nullable = true)
#  |-- component_397: float (nullable = true)
#  |-- component_398: float (nullable = true)
#  |-- component_399: float (nullable = true)
#  |-- component_400: float (nullable = true)
#  |-- component_401: float (nullable = true)
#  |-- component_402: float (nullable = true)
#  |-- component_403: float (nullable = true)
#  |-- component_404: float (nullable = true)
#  |-- component_405: float (nullable = true)
#  |-- component_406: float (nullable = true)
#  |-- component_407: float (nullable = true)
#  |-- component_408: float (nullable = true)
#  |-- component_409: float (nullable = true)
#  |-- component_410: float (nullable = true)
#  |-- component_411: float (nullable = true)
#  |-- component_412: float (nullable = true)
#  |-- component_413: float (nullable = true)
#  |-- component_414: float (nullable = true)
#  |-- component_415: float (nullable = true)
#  |-- component_416: float (nullable = true)
#  |-- component_417: float (nullable = true)
#  |-- component_418: float (nullable = true)
#  |-- component_419: float (nullable = true)
#  |-- component_420: float (nullable = true)
#  |-- component_421: float (nullable = true)
#  |-- component_422: float (nullable = true)
#  |-- component_423: float (nullable = true)
#  |-- component_424: float (nullable = true)
#  |-- component_425: float (nullable = true)
#  |-- component_426: float (nullable = true)
#  |-- component_427: float (nullable = true)
#  |-- component_428: float (nullable = true)
#  |-- component_429: float (nullable = true)
#  |-- component_430: float (nullable = true)
#  |-- component_431: float (nullable = true)
#  |-- component_432: float (nullable = true)
#  |-- component_433: float (nullable = true)
#  |-- component_434: float (nullable = true)
#  |-- component_435: float (nullable = true)
#  |-- component_436: float (nullable = true)
#  |-- component_437: float (nullable = true)
#  |-- component_438: float (nullable = true)
#  |-- component_439: float (nullable = true)
#  |-- component_440: float (nullable = true)
#  |-- component_441: float (nullable = true)
#  |-- component_442: float (nullable = true)
#  |-- component_443: float (nullable = true)
#  |-- component_444: float (nullable = true)
#  |-- component_445: float (nullable = true)
#  |-- component_446: float (nullable = true)
#  |-- component_447: float (nullable = true)
#  |-- component_448: float (nullable = true)
#  |-- component_449: float (nullable = true)
#  |-- component_450: float (nullable = true)
#  |-- component_451: float (nullable = true)
#  |-- component_452: float (nullable = true)
#  |-- component_453: float (nullable = true)
#  |-- component_454: float (nullable = true)
#  |-- component_455: float (nullable = true)
#  |-- component_456: float (nullable = true)
#  |-- component_457: float (nullable = true)
#  |-- component_458: float (nullable = true)
#  |-- component_459: float (nullable = true)
#  |-- component_460: float (nullable = true)
#  |-- component_461: float (nullable = true)
#  |-- component_462: float (nullable = true)
#  |-- component_463: float (nullable = true)
#  |-- component_464: float (nullable = true)
#  |-- component_465: float (nullable = true)
#  |-- component_466: float (nullable = true)
#  |-- component_467: float (nullable = true)
#  |-- component_468: float (nullable = true)
#  |-- component_469: float (nullable = true)
#  |-- component_470: float (nullable = true)
#  |-- component_471: float (nullable = true)
#  |-- component_472: float (nullable = true)
#  |-- component_473: float (nullable = true)
#  |-- component_474: float (nullable = true)
#  |-- component_475: float (nullable = true)
#  |-- component_476: float (nullable = true)
#  |-- component_477: float (nullable = true)
#  |-- component_478: float (nullable = true)
#  |-- component_479: float (nullable = true)
#  |-- component_480: float (nullable = true)
#  |-- component_481: float (nullable = true)
#  |-- component_482: float (nullable = true)
#  |-- component_483: float (nullable = true)
#  |-- component_484: float (nullable = true)
#  |-- component_485: float (nullable = true)
#  |-- component_486: float (nullable = true)
#  |-- component_487: float (nullable = true)
#  |-- component_488: float (nullable = true)
#  |-- component_489: float (nullable = true)
#  |-- component_490: float (nullable = true)
#  |-- component_491: float (nullable = true)
#  |-- component_492: float (nullable = true)
#  |-- component_493: float (nullable = true)
#  |-- component_494: float (nullable = true)
#  |-- component_495: float (nullable = true)
#  |-- component_496: float (nullable = true)
#  |-- component_497: float (nullable = true)
#  |-- component_498: float (nullable = true)
#  |-- component_499: float (nullable = true)
#  |-- component_500: float (nullable = true)
#  |-- component_501: float (nullable = true)
#  |-- component_502: float (nullable = true)
#  |-- component_503: float (nullable = true)
#  |-- component_504: float (nullable = true)
#  |-- component_505: float (nullable = true)
#  |-- component_506: float (nullable = true)
#  |-- component_507: float (nullable = true)
#  |-- component_508: float (nullable = true)
#  |-- component_509: float (nullable = true)
#  |-- component_510: float (nullable = true)
#  |-- component_511: float (nullable = true)
#  |-- component_512: float (nullable = true)
#  |-- component_513: float (nullable = true)
#  |-- component_514: float (nullable = true)
#  |-- component_515: float (nullable = true)
#  |-- component_516: float (nullable = true)
#  |-- component_517: float (nullable = true)
#  |-- component_518: float (nullable = true)
#  |-- component_519: float (nullable = true)
#  |-- component_520: float (nullable = true)
#  |-- component_521: float (nullable = true)
#  |-- component_522: float (nullable = true)
#  |-- component_523: float (nullable = true)
#  |-- component_524: float (nullable = true)
#  |-- component_525: float (nullable = true)
#  |-- component_526: float (nullable = true)
#  |-- component_527: float (nullable = true)
#  |-- component_528: float (nullable = true)
#  |-- component_529: float (nullable = true)
#  |-- component_530: float (nullable = true)
#  |-- component_531: float (nullable = true)
#  |-- component_532: float (nullable = true)
#  |-- component_533: float (nullable = true)
#  |-- component_534: float (nullable = true)
#  |-- component_535: float (nullable = true)
#  |-- component_536: float (nullable = true)
#  |-- component_537: float (nullable = true)
#  |-- component_538: float (nullable = true)
#  |-- component_539: float (nullable = true)
#  |-- component_540: float (nullable = true)
#  |-- component_541: float (nullable = true)
#  |-- component_542: float (nullable = true)
#  |-- component_543: float (nullable = true)
#  |-- component_544: float (nullable = true)
#  |-- component_545: float (nullable = true)
#  |-- component_546: float (nullable = true)
#  |-- component_547: float (nullable = true)
#  |-- component_548: float (nullable = true)
#  |-- component_549: float (nullable = true)
#  |-- component_550: float (nullable = true)
#  |-- component_551: float (nullable = true)
#  |-- component_552: float (nullable = true)
#  |-- component_553: float (nullable = true)
#  |-- component_554: float (nullable = true)
#  |-- component_555: float (nullable = true)
#  |-- component_556: float (nullable = true)
#  |-- component_557: float (nullable = true)
#  |-- component_558: float (nullable = true)
#  |-- component_559: float (nullable = true)
#  |-- component_560: float (nullable = true)
#  |-- component_561: float (nullable = true)
#  |-- component_562: float (nullable = true)
#  |-- component_563: float (nullable = true)
#  |-- component_564: float (nullable = true)
#  |-- component_565: float (nullable = true)
#  |-- component_566: float (nullable = true)
#  |-- component_567: float (nullable = true)
#  |-- component_568: float (nullable = true)
#  |-- component_569: float (nullable = true)
#  |-- component_570: float (nullable = true)
#  |-- component_571: float (nullable = true)
#  |-- component_572: float (nullable = true)
#  |-- component_573: float (nullable = true)
#  |-- component_574: float (nullable = true)
#  |-- component_575: float (nullable = true)
#  |-- component_576: float (nullable = true)
#  |-- component_577: float (nullable = true)
#  |-- component_578: float (nullable = true)
#  |-- component_579: float (nullable = true)
#  |-- component_580: float (nullable = true)
#  |-- component_581: float (nullable = true)
#  |-- component_582: float (nullable = true)
#  |-- component_583: float (nullable = true)
#  |-- component_584: float (nullable = true)
#  |-- component_585: float (nullable = true)
#  |-- component_586: float (nullable = true)
#  |-- component_587: float (nullable = true)
#  |-- component_588: float (nullable = true)
#  |-- component_589: float (nullable = true)
#  |-- component_590: float (nullable = true)
#  |-- component_591: float (nullable = true)
#  |-- component_592: float (nullable = true)
#  |-- component_593: float (nullable = true)
#  |-- component_594: float (nullable = true)
#  |-- component_595: float (nullable = true)
#  |-- component_596: float (nullable = true)
#  |-- component_597: float (nullable = true)
#  |-- component_598: float (nullable = true)
#  |-- component_599: float (nullable = true)
#  |-- component_600: float (nullable = true)
#  |-- component_601: float (nullable = true)
#  |-- component_602: float (nullable = true)
#  |-- component_603: float (nullable = true)
#  |-- component_604: float (nullable = true)
#  |-- component_605: float (nullable = true)
#  |-- component_606: float (nullable = true)
#  |-- component_607: float (nullable = true)
#  |-- component_608: float (nullable = true)
#  |-- component_609: float (nullable = true)
#  |-- component_610: float (nullable = true)
#  |-- component_611: float (nullable = true)
#  |-- component_612: float (nullable = true)
#  |-- component_613: float (nullable = true)
#  |-- component_614: float (nullable = true)
#  |-- component_615: float (nullable = true)
#  |-- component_616: float (nullable = true)
#  |-- component_617: float (nullable = true)
#  |-- component_618: float (nullable = true)
#  |-- component_619: float (nullable = true)
#  |-- component_620: float (nullable = true)
#  |-- component_621: float (nullable = true)
#  |-- component_622: float (nullable = true)
#  |-- component_623: float (nullable = true)
#  |-- component_624: float (nullable = true)
#  |-- component_625: float (nullable = true)
#  |-- component_626: float (nullable = true)
#  |-- component_627: float (nullable = true)
#  |-- component_628: float (nullable = true)
#  |-- component_629: float (nullable = true)
#  |-- component_630: float (nullable = true)
#  |-- component_631: float (nullable = true)
#  |-- component_632: float (nullable = true)
#  |-- component_633: float (nullable = true)
#  |-- component_634: float (nullable = true)
#  |-- component_635: float (nullable = true)
#  |-- component_636: float (nullable = true)
#  |-- component_637: float (nullable = true)
#  |-- component_638: float (nullable = true)
#  |-- component_639: float (nullable = true)
#  |-- component_640: float (nullable = true)
#  |-- component_641: float (nullable = true)
#  |-- component_642: float (nullable = true)
#  |-- component_643: float (nullable = true)
#  |-- component_644: float (nullable = true)
#  |-- component_645: float (nullable = true)
#  |-- component_646: float (nullable = true)
#  |-- component_647: float (nullable = true)
#  |-- component_648: float (nullable = true)
#  |-- component_649: float (nullable = true)
#  |-- component_650: float (nullable = true)
#  |-- component_651: float (nullable = true)
#  |-- component_652: float (nullable = true)
#  |-- component_653: float (nullable = true)
#  |-- component_654: float (nullable = true)
#  |-- component_655: float (nullable = true)
#  |-- component_656: float (nullable = true)
#  |-- component_657: float (nullable = true)
#  |-- component_658: float (nullable = true)
#  |-- component_659: float (nullable = true)
#  |-- component_660: float (nullable = true)
#  |-- component_661: float (nullable = true)
#  |-- component_662: float (nullable = true)
#  |-- component_663: float (nullable = true)
#  |-- component_664: float (nullable = true)
#  |-- component_665: float (nullable = true)
#  |-- component_666: float (nullable = true)
#  |-- component_667: float (nullable = true)
#  |-- component_668: float (nullable = true)
#  |-- component_669: float (nullable = true)
#  |-- component_670: float (nullable = true)
#  |-- component_671: float (nullable = true)
#  |-- component_672: float (nullable = true)
#  |-- component_673: float (nullable = true)
#  |-- component_674: float (nullable = true)
#  |-- component_675: float (nullable = true)
#  |-- component_676: float (nullable = true)
#  |-- component_677: float (nullable = true)
#  |-- component_678: float (nullable = true)
#  |-- component_679: float (nullable = true)
#  |-- component_680: float (nullable = true)
#  |-- component_681: float (nullable = true)
#  |-- component_682: float (nullable = true)
#  |-- component_683: float (nullable = true)
#  |-- component_684: float (nullable = true)
#  |-- component_685: float (nullable = true)
#  |-- component_686: float (nullable = true)
#  |-- component_687: float (nullable = true)
#  |-- component_688: float (nullable = true)
#  |-- component_689: float (nullable = true)
#  |-- component_690: float (nullable = true)
#  |-- component_691: float (nullable = true)
#  |-- component_692: float (nullable = true)
#  |-- component_693: float (nullable = true)
#  |-- component_694: float (nullable = true)
#  |-- component_695: float (nullable = true)
#  |-- component_696: float (nullable = true)
#  |-- component_697: float (nullable = true)
#  |-- component_698: float (nullable = true)
#  |-- component_699: float (nullable = true)
#  |-- component_700: float (nullable = true)
#  |-- component_701: float (nullable = true)
#  |-- component_702: float (nullable = true)
#  |-- component_703: float (nullable = true)
#  |-- component_704: float (nullable = true)
#  |-- component_705: float (nullable = true)
#  |-- component_706: float (nullable = true)
#  |-- component_707: float (nullable = true)
#  |-- component_708: float (nullable = true)
#  |-- component_709: float (nullable = true)
#  |-- component_710: float (nullable = true)
#  |-- component_711: float (nullable = true)
#  |-- component_712: float (nullable = true)
#  |-- component_713: float (nullable = true)
#  |-- component_714: float (nullable = true)
#  |-- component_715: float (nullable = true)
#  |-- component_716: float (nullable = true)
#  |-- component_717: float (nullable = true)
#  |-- component_718: float (nullable = true)
#  |-- component_719: float (nullable = true)
#  |-- component_720: float (nullable = true)
#  |-- component_721: float (nullable = true)
#  |-- component_722: float (nullable = true)
#  |-- component_723: float (nullable = true)
#  |-- component_724: float (nullable = true)
#  |-- component_725: float (nullable = true)
#  |-- component_726: float (nullable = true)
#  |-- component_727: float (nullable = true)
#  |-- component_728: float (nullable = true)
#  |-- component_729: float (nullable = true)
#  |-- component_730: float (nullable = true)
#  |-- component_731: float (nullable = true)
#  |-- component_732: float (nullable = true)
#  |-- component_733: float (nullable = true)
#  |-- component_734: float (nullable = true)
#  |-- component_735: float (nullable = true)
#  |-- component_736: float (nullable = true)
#  |-- component_737: float (nullable = true)
#  |-- component_738: float (nullable = true)
#  |-- component_739: float (nullable = true)
#  |-- component_740: float (nullable = true)
#  |-- component_741: float (nullable = true)
#  |-- component_742: float (nullable = true)
#  |-- component_743: float (nullable = true)
#  |-- component_744: float (nullable = true)
#  |-- component_745: float (nullable = true)
#  |-- component_746: float (nullable = true)
#  |-- component_747: float (nullable = true)
#  |-- component_748: float (nullable = true)
#  |-- component_749: float (nullable = true)
#  |-- component_750: float (nullable = true)
#  |-- component_751: float (nullable = true)
#  |-- component_752: float (nullable = true)
#  |-- component_753: float (nullable = true)
#  |-- component_754: float (nullable = true)
#  |-- component_755: float (nullable = true)
#  |-- component_756: float (nullable = true)
#  |-- component_757: float (nullable = true)
#  |-- component_758: float (nullable = true)
#  |-- component_759: float (nullable = true)
#  |-- component_760: float (nullable = true)
#  |-- component_761: float (nullable = true)
#  |-- component_762: float (nullable = true)
#  |-- component_763: float (nullable = true)
#  |-- component_764: float (nullable = true)
#  |-- component_765: float (nullable = true)
#  |-- component_766: float (nullable = true)
#  |-- component_767: float (nullable = true)
#  |-- component_768: float (nullable = true)
#  |-- component_769: float (nullable = true)
#  |-- component_770: float (nullable = true)
#  |-- component_771: float (nullable = true)
#  |-- component_772: float (nullable = true)
#  |-- component_773: float (nullable = true)
#  |-- component_774: float (nullable = true)
#  |-- component_775: float (nullable = true)
#  |-- component_776: float (nullable = true)
#  |-- component_777: float (nullable = true)
#  |-- component_778: float (nullable = true)
#  |-- component_779: float (nullable = true)
#  |-- component_780: float (nullable = true)
#  |-- component_781: float (nullable = true)
#  |-- component_782: float (nullable = true)
#  |-- component_783: float (nullable = true)
#  |-- component_784: float (nullable = true)
#  |-- component_785: float (nullable = true)
#  |-- component_786: float (nullable = true)
#  |-- component_787: float (nullable = true)
#  |-- component_788: float (nullable = true)
#  |-- component_789: float (nullable = true)
#  |-- component_790: float (nullable = true)
#  |-- component_791: float (nullable = true)
#  |-- component_792: float (nullable = true)
#  |-- component_793: float (nullable = true)
#  |-- component_794: float (nullable = true)
#  |-- component_795: float (nullable = true)
#  |-- component_796: float (nullable = true)
#  |-- component_797: float (nullable = true)
#  |-- component_798: float (nullable = true)
#  |-- component_799: float (nullable = true)
#  |-- component_800: float (nullable = true)
#  |-- component_801: float (nullable = true)
#  |-- component_802: float (nullable = true)
#  |-- component_803: float (nullable = true)
#  |-- component_804: float (nullable = true)
#  |-- component_805: float (nullable = true)
#  |-- component_806: float (nullable = true)
#  |-- component_807: float (nullable = true)
#  |-- component_808: float (nullable = true)
#  |-- component_809: float (nullable = true)
#  |-- component_810: float (nullable = true)
#  |-- component_811: float (nullable = true)
#  |-- component_812: float (nullable = true)
#  |-- component_813: float (nullable = true)
#  |-- component_814: float (nullable = true)
#  |-- component_815: float (nullable = true)
#  |-- component_816: float (nullable = true)
#  |-- component_817: float (nullable = true)
#  |-- component_818: float (nullable = true)
#  |-- component_819: float (nullable = true)
#  |-- component_820: float (nullable = true)
#  |-- component_821: float (nullable = true)
#  |-- component_822: float (nullable = true)
#  |-- component_823: float (nullable = true)
#  |-- component_824: float (nullable = true)
#  |-- component_825: float (nullable = true)
#  |-- component_826: float (nullable = true)
#  |-- component_827: float (nullable = true)
#  |-- component_828: float (nullable = true)
#  |-- component_829: float (nullable = true)
#  |-- component_830: float (nullable = true)
#  |-- component_831: float (nullable = true)
#  |-- component_832: float (nullable = true)
#  |-- component_833: float (nullable = true)
#  |-- component_834: float (nullable = true)
#  |-- component_835: float (nullable = true)
#  |-- component_836: float (nullable = true)
#  |-- component_837: float (nullable = true)
#  |-- component_838: float (nullable = true)
#  |-- component_839: float (nullable = true)
#  |-- component_840: float (nullable = true)
#  |-- component_841: float (nullable = true)
#  |-- component_842: float (nullable = true)
#  |-- component_843: float (nullable = true)
#  |-- component_844: float (nullable = true)
#  |-- component_845: float (nullable = true)
#  |-- component_846: float (nullable = true)
#  |-- component_847: float (nullable = true)
#  |-- component_848: float (nullable = true)
#  |-- component_849: float (nullable = true)
#  |-- component_850: float (nullable = true)
#  |-- component_851: float (nullable = true)
#  |-- component_852: float (nullable = true)
#  |-- component_853: float (nullable = true)
#  |-- component_854: float (nullable = true)
#  |-- component_855: float (nullable = true)
#  |-- component_856: float (nullable = true)
#  |-- component_857: float (nullable = true)
#  |-- component_858: float (nullable = true)
#  |-- component_859: float (nullable = true)
#  |-- component_860: float (nullable = true)
#  |-- component_861: float (nullable = true)
#  |-- component_862: float (nullable = true)
#  |-- component_863: float (nullable = true)
#  |-- component_864: float (nullable = true)
#  |-- component_865: float (nullable = true)
#  |-- component_866: float (nullable = true)
#  |-- component_867: float (nullable = true)
#  |-- component_868: float (nullable = true)
#  |-- component_869: float (nullable = true)
#  |-- component_870: float (nullable = true)
#  |-- component_871: float (nullable = true)
#  |-- component_872: float (nullable = true)
#  |-- component_873: float (nullable = true)
#  |-- component_874: float (nullable = true)
#  |-- component_875: float (nullable = true)
#  |-- component_876: float (nullable = true)
#  |-- component_877: float (nullable = true)
#  |-- component_878: float (nullable = true)
#  |-- component_879: float (nullable = true)
#  |-- component_880: float (nullable = true)
#  |-- component_881: float (nullable = true)
#  |-- component_882: float (nullable = true)
#  |-- component_883: float (nullable = true)
#  |-- component_884: float (nullable = true)
#  |-- component_885: float (nullable = true)
#  |-- component_886: float (nullable = true)
#  |-- component_887: float (nullable = true)
#  |-- component_888: float (nullable = true)
#  |-- component_889: float (nullable = true)
#  |-- component_890: float (nullable = true)
#  |-- component_891: float (nullable = true)
#  |-- component_892: float (nullable = true)
#  |-- component_893: float (nullable = true)
#  |-- component_894: float (nullable = true)
#  |-- component_895: float (nullable = true)
#  |-- component_896: float (nullable = true)
#  |-- component_897: float (nullable = true)
#  |-- component_898: float (nullable = true)
#  |-- component_899: float (nullable = true)
#  |-- component_900: float (nullable = true)
#  |-- component_901: float (nullable = true)
#  |-- component_902: float (nullable = true)
#  |-- component_903: float (nullable = true)
#  |-- component_904: float (nullable = true)
#  |-- component_905: float (nullable = true)
#  |-- component_906: float (nullable = true)
#  |-- component_907: float (nullable = true)
#  |-- component_908: float (nullable = true)
#  |-- component_909: float (nullable = true)
#  |-- component_910: float (nullable = true)
#  |-- component_911: float (nullable = true)
#  |-- component_912: float (nullable = true)
#  |-- component_913: float (nullable = true)
#  |-- component_914: float (nullable = true)
#  |-- component_915: float (nullable = true)
#  |-- component_916: float (nullable = true)
#  |-- component_917: float (nullable = true)
#  |-- component_918: float (nullable = true)
#  |-- component_919: float (nullable = true)
#  |-- component_920: float (nullable = true)
#  |-- component_921: float (nullable = true)
#  |-- component_922: float (nullable = true)
#  |-- component_923: float (nullable = true)
#  |-- component_924: float (nullable = true)
#  |-- component_925: float (nullable = true)
#  |-- component_926: float (nullable = true)
#  |-- component_927: float (nullable = true)
#  |-- component_928: float (nullable = true)
#  |-- component_929: float (nullable = true)
#  |-- component_930: float (nullable = true)
#  |-- component_931: float (nullable = true)
#  |-- component_932: float (nullable = true)
#  |-- component_933: float (nullable = true)
#  |-- component_934: float (nullable = true)
#  |-- component_935: float (nullable = true)
#  |-- component_936: float (nullable = true)
#  |-- component_937: float (nullable = true)
#  |-- component_938: float (nullable = true)
#  |-- component_939: float (nullable = true)
#  |-- component_940: float (nullable = true)
#  |-- component_941: float (nullable = true)
#  |-- component_942: float (nullable = true)
#  |-- component_943: float (nullable = true)
#  |-- component_944: float (nullable = true)
#  |-- component_945: float (nullable = true)
#  |-- component_946: float (nullable = true)
#  |-- component_947: float (nullable = true)
#  |-- component_948: float (nullable = true)
#  |-- component_949: float (nullable = true)
#  |-- component_950: float (nullable = true)
#  |-- component_951: float (nullable = true)
#  |-- component_952: float (nullable = true)
#  |-- component_953: float (nullable = true)
#  |-- component_954: float (nullable = true)
#  |-- component_955: float (nullable = true)
#  |-- component_956: float (nullable = true)
#  |-- component_957: float (nullable = true)
#  |-- component_958: float (nullable = true)
#  |-- component_959: float (nullable = true)
#  |-- component_960: float (nullable = true)
#  |-- component_961: float (nullable = true)
#  |-- component_962: float (nullable = true)
#  |-- component_963: float (nullable = true)
#  |-- component_964: float (nullable = true)
#  |-- component_965: float (nullable = true)
#  |-- component_966: float (nullable = true)
#  |-- component_967: float (nullable = true)
#  |-- component_968: float (nullable = true)
#  |-- component_969: float (nullable = true)
#  |-- component_970: float (nullable = true)
#  |-- component_971: float (nullable = true)
#  |-- component_972: float (nullable = true)
#  |-- component_973: float (nullable = true)
#  |-- component_974: float (nullable = true)
#  |-- component_975: float (nullable = true)
#  |-- component_976: float (nullable = true)
#  |-- component_977: float (nullable = true)
#  |-- component_978: float (nullable = true)
#  |-- component_979: float (nullable = true)
#  |-- component_980: float (nullable = true)
#  |-- component_981: float (nullable = true)
#  |-- component_982: float (nullable = true)
#  |-- component_983: float (nullable = true)
#  |-- component_984: float (nullable = true)
#  |-- component_985: float (nullable = true)
#  |-- component_986: float (nullable = true)
#  |-- component_987: float (nullable = true)
#  |-- component_988: float (nullable = true)
#  |-- component_989: float (nullable = true)
#  |-- component_990: float (nullable = true)
#  |-- component_991: float (nullable = true)
#  |-- component_992: float (nullable = true)
#  |-- component_993: float (nullable = true)
#  |-- component_994: float (nullable = true)
#  |-- component_995: float (nullable = true)
#  |-- component_996: float (nullable = true)
#  |-- component_997: float (nullable = true)
#  |-- component_998: float (nullable = true)
#  |-- component_999: float (nullable = true)
#  |-- component_1000: float (nullable = true)
#  |-- component_1001: float (nullable = true)
#  |-- component_1002: float (nullable = true)
#  |-- component_1003: float (nullable = true)
#  |-- component_1004: float (nullable = true)
#  |-- component_1005: float (nullable = true)
#  |-- component_1006: float (nullable = true)
#  |-- component_1007: float (nullable = true)
#  |-- component_1008: float (nullable = true)
#  |-- component_1009: float (nullable = true)
#  |-- component_1010: float (nullable = true)
#  |-- component_1011: float (nullable = true)
#  |-- component_1012: float (nullable = true)
#  |-- component_1013: float (nullable = true)
#  |-- component_1014: float (nullable = true)
#  |-- component_1015: float (nullable = true)
#  |-- component_1016: float (nullable = true)
#  |-- component_1017: float (nullable = true)
#  |-- component_1018: float (nullable = true)
#  |-- component_1019: float (nullable = true)
#  |-- component_1020: float (nullable = true)
#  |-- component_1021: float (nullable = true)
#  |-- component_1022: float (nullable = true)
#  |-- component_1023: float (nullable = true)
#  |-- component_1024: float (nullable = true)
#  |-- component_1025: float (nullable = true)
#  |-- component_1026: float (nullable = true)
#  |-- component_1027: float (nullable = true)
#  |-- component_1028: float (nullable = true)
#  |-- component_1029: float (nullable = true)
#  |-- component_1030: float (nullable = true)
#  |-- component_1031: float (nullable = true)
#  |-- component_1032: float (nullable = true)
#  |-- component_1033: float (nullable = true)
#  |-- component_1034: float (nullable = true)
#  |-- component_1035: float (nullable = true)
#  |-- component_1036: float (nullable = true)
#  |-- component_1037: float (nullable = true)
#  |-- component_1038: float (nullable = true)
#  |-- component_1039: float (nullable = true)
#  |-- component_1040: float (nullable = true)
#  |-- component_1041: float (nullable = true)
#  |-- component_1042: float (nullable = true)
#  |-- component_1043: float (nullable = true)
#  |-- component_1044: float (nullable = true)
#  |-- component_1045: float (nullable = true)
#  |-- component_1046: float (nullable = true)
#  |-- component_1047: float (nullable = true)
#  |-- component_1048: float (nullable = true)
#  |-- component_1049: float (nullable = true)
#  |-- component_1050: float (nullable = true)
#  |-- component_1051: float (nullable = true)
#  |-- component_1052: float (nullable = true)
#  |-- component_1053: float (nullable = true)
#  |-- component_1054: float (nullable = true)
#  |-- component_1055: float (nullable = true)
#  |-- component_1056: float (nullable = true)
#  |-- component_1057: float (nullable = true)
#  |-- component_1058: float (nullable = true)
#  |-- component_1059: float (nullable = true)
#  |-- component_1060: float (nullable = true)
#  |-- component_1061: float (nullable = true)
#  |-- component_1062: float (nullable = true)
#  |-- component_1063: float (nullable = true)
#  |-- component_1064: float (nullable = true)
#  |-- component_1065: float (nullable = true)
#  |-- component_1066: float (nullable = true)
#  |-- component_1067: float (nullable = true)
#  |-- component_1068: float (nullable = true)
#  |-- component_1069: float (nullable = true)
#  |-- component_1070: float (nullable = true)
#  |-- component_1071: float (nullable = true)
#  |-- component_1072: float (nullable = true)
#  |-- component_1073: float (nullable = true)
#  |-- component_1074: float (nullable = true)
#  |-- component_1075: float (nullable = true)
#  |-- component_1076: float (nullable = true)
#  |-- component_1077: float (nullable = true)
#  |-- component_1078: float (nullable = true)
#  |-- component_1079: float (nullable = true)
#  |-- component_1080: float (nullable = true)
#  |-- component_1081: float (nullable = true)
#  |-- component_1082: float (nullable = true)
#  |-- component_1083: float (nullable = true)
#  |-- component_1084: float (nullable = true)
#  |-- component_1085: float (nullable = true)
#  |-- component_1086: float (nullable = true)
#  |-- component_1087: float (nullable = true)
#  |-- component_1088: float (nullable = true)
#  |-- component_1089: float (nullable = true)
#  |-- component_1090: float (nullable = true)
#  |-- component_1091: float (nullable = true)
#  |-- component_1092: float (nullable = true)
#  |-- component_1093: float (nullable = true)
#  |-- component_1094: float (nullable = true)
#  |-- component_1095: float (nullable = true)
#  |-- component_1096: float (nullable = true)
#  |-- component_1097: float (nullable = true)
#  |-- component_1098: float (nullable = true)
#  |-- component_1099: float (nullable = true)
#  |-- component_1100: float (nullable = true)
#  |-- component_1101: float (nullable = true)
#  |-- component_1102: float (nullable = true)
#  |-- component_1103: float (nullable = true)
#  |-- component_1104: float (nullable = true)
#  |-- component_1105: float (nullable = true)
#  |-- component_1106: float (nullable = true)
#  |-- component_1107: float (nullable = true)
#  |-- component_1108: float (nullable = true)
#  |-- component_1109: float (nullable = true)
#  |-- component_1110: float (nullable = true)
#  |-- component_1111: float (nullable = true)
#  |-- component_1112: float (nullable = true)
#  |-- component_1113: float (nullable = true)
#  |-- component_1114: float (nullable = true)
#  |-- component_1115: float (nullable = true)
#  |-- component_1116: float (nullable = true)
#  |-- component_1117: float (nullable = true)
#  |-- component_1118: float (nullable = true)
#  |-- component_1119: float (nullable = true)
#  |-- component_1120: float (nullable = true)
#  |-- component_1121: float (nullable = true)
#  |-- component_1122: float (nullable = true)
#  |-- component_1123: float (nullable = true)
#  |-- component_1124: float (nullable = true)
#  |-- component_1125: float (nullable = true)
#  |-- component_1126: float (nullable = true)
#  |-- component_1127: float (nullable = true)
#  |-- component_1128: float (nullable = true)
#  |-- component_1129: float (nullable = true)
#  |-- component_1130: float (nullable = true)
#  |-- component_1131: float (nullable = true)
#  |-- component_1132: float (nullable = true)
#  |-- component_1133: float (nullable = true)
#  |-- component_1134: float (nullable = true)
#  |-- component_1135: float (nullable = true)
#  |-- component_1136: float (nullable = true)
#  |-- component_1137: float (nullable = true)
#  |-- component_1138: float (nullable = true)
#  |-- component_1139: float (nullable = true)
#  |-- component_1140: float (nullable = true)
#  |-- component_1141: float (nullable = true)
#  |-- component_1142: float (nullable = true)
#  |-- component_1143: float (nullable = true)
#  |-- component_1144: float (nullable = true)
#  |-- component_1145: float (nullable = true)
#  |-- component_1146: float (nullable = true)
#  |-- component_1147: float (nullable = true)
#  |-- component_1148: float (nullable = true)
#  |-- component_1149: float (nullable = true)
#  |-- component_1150: float (nullable = true)
#  |-- component_1151: float (nullable = true)
#  |-- component_1152: float (nullable = true)
#  |-- component_1153: float (nullable = true)
#  |-- component_1154: float (nullable = true)
#  |-- component_1155: float (nullable = true)
#  |-- component_1156: float (nullable = true)
#  |-- component_1157: float (nullable = true)
#  |-- component_1158: float (nullable = true)
#  |-- component_1159: float (nullable = true)
#  |-- component_1160: float (nullable = true)
#  |-- component_1161: float (nullable = true)
#  |-- component_1162: float (nullable = true)
#  |-- component_1163: float (nullable = true)
#  |-- component_1164: float (nullable = true)
#  |-- component_1165: float (nullable = true)
#  |-- component_1166: float (nullable = true)
#  |-- component_1167: float (nullable = true)
#  |-- component_1168: float (nullable = true)
#  |-- component_1169: float (nullable = true)
#  |-- component_1170: float (nullable = true)
#  |-- component_1171: float (nullable = true)
#  |-- component_1172: float (nullable = true)
#  |-- component_1173: float (nullable = true)
#  |-- component_1174: float (nullable = true)
#  |-- component_1175: float (nullable = true)
#  |-- component_1176: float (nullable = true)
#  |-- component_1177: float (nullable = true)
#  |-- component_1178: float (nullable = true)
#  |-- component_1179: float (nullable = true)
#  |-- component_1180: float (nullable = true)
#  |-- component_1181: float (nullable = true)
#  |-- component_1182: float (nullable = true)
#  |-- component_1183: float (nullable = true)
#  |-- component_1184: float (nullable = true)
#  |-- component_1185: float (nullable = true)
#  |-- component_1186: float (nullable = true)
#  |-- component_1187: float (nullable = true)
#  |-- component_1188: float (nullable = true)
#  |-- component_1189: float (nullable = true)
#  |-- component_1190: float (nullable = true)
#  |-- component_1191: float (nullable = true)
#  |-- component_1192: float (nullable = true)
#  |-- component_1193: float (nullable = true)
#  |-- component_1194: float (nullable = true)
#  |-- component_1195: float (nullable = true)
#  |-- component_1196: float (nullable = true)
#  |-- component_1197: float (nullable = true)
#  |-- component_1198: float (nullable = true)
#  |-- component_1199: float (nullable = true)
#  |-- component_1200: float (nullable = true)
#  |-- component_1201: float (nullable = true)
#  |-- component_1202: float (nullable = true)
#  |-- component_1203: float (nullable = true)
#  |-- component_1204: float (nullable = true)
#  |-- component_1205: float (nullable = true)
#  |-- component_1206: float (nullable = true)
#  |-- component_1207: float (nullable = true)
#  |-- component_1208: float (nullable = true)
#  |-- component_1209: float (nullable = true)
#  |-- component_1210: float (nullable = true)
#  |-- component_1211: float (nullable = true)
#  |-- component_1212: float (nullable = true)
#  |-- component_1213: float (nullable = true)
#  |-- component_1214: float (nullable = true)
#  |-- component_1215: float (nullable = true)
#  |-- component_1216: float (nullable = true)
#  |-- component_1217: float (nullable = true)
#  |-- component_1218: float (nullable = true)
#  |-- component_1219: float (nullable = true)
#  |-- component_1220: float (nullable = true)
#  |-- component_1221: float (nullable = true)
#  |-- component_1222: float (nullable = true)
#  |-- component_1223: float (nullable = true)
#  |-- component_1224: float (nullable = true)
#  |-- component_1225: float (nullable = true)
#  |-- component_1226: float (nullable = true)
#  |-- component_1227: float (nullable = true)
#  |-- component_1228: float (nullable = true)
#  |-- component_1229: float (nullable = true)
#  |-- component_1230: float (nullable = true)
#  |-- component_1231: float (nullable = true)
#  |-- component_1232: float (nullable = true)
#  |-- component_1233: float (nullable = true)
#  |-- component_1234: float (nullable = true)
#  |-- component_1235: float (nullable = true)
#  |-- component_1236: float (nullable = true)
#  |-- component_1237: float (nullable = true)
#  |-- component_1238: float (nullable = true)
#  |-- component_1239: float (nullable = true)
#  |-- component_1240: float (nullable = true)
#  |-- component_1241: float (nullable = true)
#  |-- component_1242: float (nullable = true)
#  |-- component_1243: float (nullable = true)
#  |-- component_1244: float (nullable = true)
#  |-- component_1245: float (nullable = true)
#  |-- component_1246: float (nullable = true)
#  |-- component_1247: float (nullable = true)
#  |-- component_1248: float (nullable = true)
#  |-- component_1249: float (nullable = true)
#  |-- component_1250: float (nullable = true)
#  |-- component_1251: float (nullable = true)
#  |-- component_1252: float (nullable = true)
#  |-- component_1253: float (nullable = true)
#  |-- component_1254: float (nullable = true)
#  |-- component_1255: float (nullable = true)
#  |-- component_1256: float (nullable = true)
#  |-- component_1257: float (nullable = true)
#  |-- component_1258: float (nullable = true)
#  |-- component_1259: float (nullable = true)
#  |-- component_1260: float (nullable = true)
#  |-- component_1261: float (nullable = true)
#  |-- component_1262: float (nullable = true)
#  |-- component_1263: float (nullable = true)
#  |-- component_1264: float (nullable = true)
#  |-- component_1265: float (nullable = true)
#  |-- component_1266: float (nullable = true)
#  |-- component_1267: float (nullable = true)
#  |-- component_1268: float (nullable = true)
#  |-- component_1269: float (nullable = true)
#  |-- component_1270: float (nullable = true)
#  |-- component_1271: float (nullable = true)
#  |-- component_1272: float (nullable = true)
#  |-- component_1273: float (nullable = true)
#  |-- component_1274: float (nullable = true)
#  |-- component_1275: float (nullable = true)
#  |-- component_1276: float (nullable = true)
#  |-- component_1277: float (nullable = true)
#  |-- component_1278: float (nullable = true)
#  |-- component_1279: float (nullable = true)
#  |-- component_1280: float (nullable = true)

# %%
# Méthode 01
output_path = PATH_Result_csv + "/features_csv_1"
df_selected.write.csv(output_path, header=True, mode="overwrite")

# %%
# Méthode 02
output_path = PATH_Result_csv + "/features_csv_2"
df_selected.write.mode("overwrite").option("header","true").csv(output_path)

# %%
# Méthode 03
output_path = PATH_Result_csv + "/features_csv_3"
df_selected.coalesce(1).write.csv(output_path, header=True, mode="overwrite")

# %%
# Importation 01
output_path = PATH_Result_csv + "/features_csv_1"
Test_1 = pd.read_csv(output_path + "/" + ".csv")
Test_1.shape
# Out:
# (451, 1282)

# %%
output_path = PATH_Result_csv + "/features_csv_2"
Test_2 = pd.read_csv(output_path + "/" + ".csv")
Test_2.shape
# Out:
# (451, 1282)

# %%
output_path = PATH_Result_csv + "/features_csv_3"
Test_2 = pd.read_csv(output_path + "/" + ".csv")
Test_2.shape
# Out:
# (451, 1282)

# %% [markdown]
# # Test save au format csv PCA

# %%
# 18:21:00
df_pca = spark.read.parquet(PATH_Result_pca)

# %%
# 18:21:00
df_pca.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- pca_features: array (nullable = true)
#  |    |-- element: double (containsNull = true)

# %%
# 18:21:00
df_pca.show()
# Out:
# +--------------------+-----------+--------------------+
# |                path|      label|        pca_features|
# +--------------------+-----------+--------------------+
# |file:/home/daipc/...|apple_red_2|[-4.4579277138267...|
# |file:/home/daipc/...|     pear_1|[-6.9365886016231...|
# |file:/home/daipc/...| zucchini_1|[9.39008334869121...|
# |file:/home/daipc/...| zucchini_1|[6.63079878474374...|
# |file:/home/daipc/...|   carrot_1|[16.4312965586575...|
# |file:/home/daipc/...|apple_red_2|[-5.1023044471677...|
# |file:/home/daipc/...| zucchini_1|[9.34122503348220...|
# |file:/home/daipc/...|apple_red_2|[-1.1084710443346...|
# |file:/home/daipc/...|apple_red_2|[-2.3547063856848...|
# |file:/home/daipc/...|apple_red_2|[-6.1522940768051...|
# |file:/home/daipc/...|apple_red_2|[-4.8419157363350...|
# |file:/home/daipc/...|apple_red_2|[-3.0340259199311...|
# |file:/home/daipc/...| zucchini_1|[10.3705548004934...|
# |file:/home/daipc/...|     pear_1|[-5.2281617226676...|
# |file:/home/daipc/...|apple_red_2|[-3.2346384619786...|
# |file:/home/daipc/...|     pear_1|[-7.2000860373897...|
# |file:/home/daipc/...|     pear_1|[-6.0111411316457...|
# |file:/home/daipc/...|     pear_1|[-5.8766847200566...|
# |file:/home/daipc/...|     pear_1|[-6.4369151427965...|
# |file:/home/daipc/...|     pear_1|[-4.9073783695746...|
# +--------------------+-----------+--------------------+
# only showing top 20 rows

# %%
# Nombre de composante principale : 
num_components = len(df_pca.select("pca_features").first()[0]) 
num_components
# Out:
# 350

# %%
# Extraction des composante avec udf function
extract_component = udf(lambda x, i: float(x[i]), FloatType())

# %%
extract_component
# Out:
# <function __main__.<lambda>(x, i)>

# %%
for i in range(num_components):
    df_pca = df_pca.withColumn(f"component_{i+1}", extract_component("pca_features", lit(i)))

# %%
df_pca.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- pca_features: array (nullable = true)
#  |    |-- element: double (containsNull = true)
#  |-- component_1: float (nullable = true)
#  |-- component_2: float (nullable = true)
#  |-- component_3: float (nullable = true)
#  |-- component_4: float (nullable = true)
#  |-- component_5: float (nullable = true)
#  |-- component_6: float (nullable = true)
#  |-- component_7: float (nullable = true)
#  |-- component_8: float (nullable = true)
#  |-- component_9: float (nullable = true)
#  |-- component_10: float (nullable = true)
#  |-- component_11: float (nullable = true)
#  |-- component_12: float (nullable = true)
#  |-- component_13: float (nullable = true)
#  |-- component_14: float (nullable = true)
#  |-- component_15: float (nullable = true)
#  |-- component_16: float (nullable = true)
#  |-- component_17: float (nullable = true)
#  |-- component_18: float (nullable = true)
#  |-- component_19: float (nullable = true)
#  |-- component_20: float (nullable = true)
#  |-- component_21: float (nullable = true)
#  |-- component_22: float (nullable = true)
#  |-- component_23: float (nullable = true)
#  |-- component_24: float (nullable = true)
#  |-- component_25: float (nullable = true)
#  |-- component_26: float (nullable = true)
#  |-- component_27: float (nullable = true)
#  |-- component_28: float (nullable = true)
#  |-- component_29: float (nullable = true)
#  |-- component_30: float (nullable = true)
#  |-- component_31: float (nullable = true)
#  |-- component_32: float (nullable = true)
#  |-- component_33: float (nullable = true)
#  |-- component_34: float (nullable = true)
#  |-- component_35: float (nullable = true)
#  |-- component_36: float (nullable = true)
#  |-- component_37: float (nullable = true)
#  |-- component_38: float (nullable = true)
#  |-- component_39: float (nullable = true)
#  |-- component_40: float (nullable = true)
#  |-- component_41: float (nullable = true)
#  |-- component_42: float (nullable = true)
#  |-- component_43: float (nullable = true)
#  |-- component_44: float (nullable = true)
#  |-- component_45: float (nullable = true)
#  |-- component_46: float (nullable = true)
#  |-- component_47: float (nullable = true)
#  |-- component_48: float (nullable = true)
#  |-- component_49: float (nullable = true)
#  |-- component_50: float (nullable = true)
#  |-- component_51: float (nullable = true)
#  |-- component_52: float (nullable = true)
#  |-- component_53: float (nullable = true)
#  |-- component_54: float (nullable = true)
#  |-- component_55: float (nullable = true)
#  |-- component_56: float (nullable = true)
#  |-- component_57: float (nullable = true)
#  |-- component_58: float (nullable = true)
#  |-- component_59: float (nullable = true)
#  |-- component_60: float (nullable = true)
#  |-- component_61: float (nullable = true)
#  |-- component_62: float (nullable = true)
#  |-- component_63: float (nullable = true)
#  |-- component_64: float (nullable = true)
#  |-- component_65: float (nullable = true)
#  |-- component_66: float (nullable = true)
#  |-- component_67: float (nullable = true)
#  |-- component_68: float (nullable = true)
#  |-- component_69: float (nullable = true)
#  |-- component_70: float (nullable = true)
#  |-- component_71: float (nullable = true)
#  |-- component_72: float (nullable = true)
#  |-- component_73: float (nullable = true)
#  |-- component_74: float (nullable = true)
#  |-- component_75: float (nullable = true)
#  |-- component_76: float (nullable = true)
#  |-- component_77: float (nullable = true)
#  |-- component_78: float (nullable = true)
#  |-- component_79: float (nullable = true)
#  |-- component_80: float (nullable = true)
#  |-- component_81: float (nullable = true)
#  |-- component_82: float (nullable = true)
#  |-- component_83: float (nullable = true)
#  |-- component_84: float (nullable = true)
#  |-- component_85: float (nullable = true)
#  |-- component_86: float (nullable = true)
#  |-- component_87: float (nullable = true)
#  |-- component_88: float (nullable = true)
#  |-- component_89: float (nullable = true)
#  |-- component_90: float (nullable = true)
#  |-- component_91: float (nullable = true)
#  |-- component_92: float (nullable = true)
#  |-- component_93: float (nullable = true)
#  |-- component_94: float (nullable = true)
#  |-- component_95: float (nullable = true)
#  |-- component_96: float (nullable = true)
#  |-- component_97: float (nullable = true)
#  |-- component_98: float (nullable = true)
#  |-- component_99: float (nullable = true)
#  |-- component_100: float (nullable = true)
#  |-- component_101: float (nullable = true)
#  |-- component_102: float (nullable = true)
#  |-- component_103: float (nullable = true)
#  |-- component_104: float (nullable = true)
#  |-- component_105: float (nullable = true)
#  |-- component_106: float (nullable = true)
#  |-- component_107: float (nullable = true)
#  |-- component_108: float (nullable = true)
#  |-- component_109: float (nullable = true)
#  |-- component_110: float (nullable = true)
#  |-- component_111: float (nullable = true)
#  |-- component_112: float (nullable = true)
#  |-- component_113: float (nullable = true)
#  |-- component_114: float (nullable = true)
#  |-- component_115: float (nullable = true)
#  |-- component_116: float (nullable = true)
#  |-- component_117: float (nullable = true)
#  |-- component_118: float (nullable = true)
#  |-- component_119: float (nullable = true)
#  |-- component_120: float (nullable = true)
#  |-- component_121: float (nullable = true)
#  |-- component_122: float (nullable = true)
#  |-- component_123: float (nullable = true)
#  |-- component_124: float (nullable = true)
#  |-- component_125: float (nullable = true)
#  |-- component_126: float (nullable = true)
#  |-- component_127: float (nullable = true)
#  |-- component_128: float (nullable = true)
#  |-- component_129: float (nullable = true)
#  |-- component_130: float (nullable = true)
#  |-- component_131: float (nullable = true)
#  |-- component_132: float (nullable = true)
#  |-- component_133: float (nullable = true)
#  |-- component_134: float (nullable = true)
#  |-- component_135: float (nullable = true)
#  |-- component_136: float (nullable = true)
#  |-- component_137: float (nullable = true)
#  |-- component_138: float (nullable = true)
#  |-- component_139: float (nullable = true)
#  |-- component_140: float (nullable = true)
#  |-- component_141: float (nullable = true)
#  |-- component_142: float (nullable = true)
#  |-- component_143: float (nullable = true)
#  |-- component_144: float (nullable = true)
#  |-- component_145: float (nullable = true)
#  |-- component_146: float (nullable = true)
#  |-- component_147: float (nullable = true)
#  |-- component_148: float (nullable = true)
#  |-- component_149: float (nullable = true)
#  |-- component_150: float (nullable = true)
#  |-- component_151: float (nullable = true)
#  |-- component_152: float (nullable = true)
#  |-- component_153: float (nullable = true)
#  |-- component_154: float (nullable = true)
#  |-- component_155: float (nullable = true)
#  |-- component_156: float (nullable = true)
#  |-- component_157: float (nullable = true)
#  |-- component_158: float (nullable = true)
#  |-- component_159: float (nullable = true)
#  |-- component_160: float (nullable = true)
#  |-- component_161: float (nullable = true)
#  |-- component_162: float (nullable = true)
#  |-- component_163: float (nullable = true)
#  |-- component_164: float (nullable = true)
#  |-- component_165: float (nullable = true)
#  |-- component_166: float (nullable = true)
#  |-- component_167: float (nullable = true)
#  |-- component_168: float (nullable = true)
#  |-- component_169: float (nullable = true)
#  |-- component_170: float (nullable = true)
#  |-- component_171: float (nullable = true)
#  |-- component_172: float (nullable = true)
#  |-- component_173: float (nullable = true)
#  |-- component_174: float (nullable = true)
#  |-- component_175: float (nullable = true)
#  |-- component_176: float (nullable = true)
#  |-- component_177: float (nullable = true)
#  |-- component_178: float (nullable = true)
#  |-- component_179: float (nullable = true)
#  |-- component_180: float (nullable = true)
#  |-- component_181: float (nullable = true)
#  |-- component_182: float (nullable = true)
#  |-- component_183: float (nullable = true)
#  |-- component_184: float (nullable = true)
#  |-- component_185: float (nullable = true)
#  |-- component_186: float (nullable = true)
#  |-- component_187: float (nullable = true)
#  |-- component_188: float (nullable = true)
#  |-- component_189: float (nullable = true)
#  |-- component_190: float (nullable = true)
#  |-- component_191: float (nullable = true)
#  |-- component_192: float (nullable = true)
#  |-- component_193: float (nullable = true)
#  |-- component_194: float (nullable = true)
#  |-- component_195: float (nullable = true)
#  |-- component_196: float (nullable = true)
#  |-- component_197: float (nullable = true)
#  |-- component_198: float (nullable = true)
#  |-- component_199: float (nullable = true)
#  |-- component_200: float (nullable = true)
#  |-- component_201: float (nullable = true)
#  |-- component_202: float (nullable = true)
#  |-- component_203: float (nullable = true)
#  |-- component_204: float (nullable = true)
#  |-- component_205: float (nullable = true)
#  |-- component_206: float (nullable = true)
#  |-- component_207: float (nullable = true)
#  |-- component_208: float (nullable = true)
#  |-- component_209: float (nullable = true)
#  |-- component_210: float (nullable = true)
#  |-- component_211: float (nullable = true)
#  |-- component_212: float (nullable = true)
#  |-- component_213: float (nullable = true)
#  |-- component_214: float (nullable = true)
#  |-- component_215: float (nullable = true)
#  |-- component_216: float (nullable = true)
#  |-- component_217: float (nullable = true)
#  |-- component_218: float (nullable = true)
#  |-- component_219: float (nullable = true)
#  |-- component_220: float (nullable = true)
#  |-- component_221: float (nullable = true)
#  |-- component_222: float (nullable = true)
#  |-- component_223: float (nullable = true)
#  |-- component_224: float (nullable = true)
#  |-- component_225: float (nullable = true)
#  |-- component_226: float (nullable = true)
#  |-- component_227: float (nullable = true)
#  |-- component_228: float (nullable = true)
#  |-- component_229: float (nullable = true)
#  |-- component_230: float (nullable = true)
#  |-- component_231: float (nullable = true)
#  |-- component_232: float (nullable = true)
#  |-- component_233: float (nullable = true)
#  |-- component_234: float (nullable = true)
#  |-- component_235: float (nullable = true)
#  |-- component_236: float (nullable = true)
#  |-- component_237: float (nullable = true)
#  |-- component_238: float (nullable = true)
#  |-- component_239: float (nullable = true)
#  |-- component_240: float (nullable = true)
#  |-- component_241: float (nullable = true)
#  |-- component_242: float (nullable = true)
#  |-- component_243: float (nullable = true)
#  |-- component_244: float (nullable = true)
#  |-- component_245: float (nullable = true)
#  |-- component_246: float (nullable = true)
#  |-- component_247: float (nullable = true)
#  |-- component_248: float (nullable = true)
#  |-- component_249: float (nullable = true)
#  |-- component_250: float (nullable = true)
#  |-- component_251: float (nullable = true)
#  |-- component_252: float (nullable = true)
#  |-- component_253: float (nullable = true)
#  |-- component_254: float (nullable = true)
#  |-- component_255: float (nullable = true)
#  |-- component_256: float (nullable = true)
#  |-- component_257: float (nullable = true)
#  |-- component_258: float (nullable = true)
#  |-- component_259: float (nullable = true)
#  |-- component_260: float (nullable = true)
#  |-- component_261: float (nullable = true)
#  |-- component_262: float (nullable = true)
#  |-- component_263: float (nullable = true)
#  |-- component_264: float (nullable = true)
#  |-- component_265: float (nullable = true)
#  |-- component_266: float (nullable = true)
#  |-- component_267: float (nullable = true)
#  |-- component_268: float (nullable = true)
#  |-- component_269: float (nullable = true)
#  |-- component_270: float (nullable = true)
#  |-- component_271: float (nullable = true)
#  |-- component_272: float (nullable = true)
#  |-- component_273: float (nullable = true)
#  |-- component_274: float (nullable = true)
#  |-- component_275: float (nullable = true)
#  |-- component_276: float (nullable = true)
#  |-- component_277: float (nullable = true)
#  |-- component_278: float (nullable = true)
#  |-- component_279: float (nullable = true)
#  |-- component_280: float (nullable = true)
#  |-- component_281: float (nullable = true)
#  |-- component_282: float (nullable = true)
#  |-- component_283: float (nullable = true)
#  |-- component_284: float (nullable = true)
#  |-- component_285: float (nullable = true)
#  |-- component_286: float (nullable = true)
#  |-- component_287: float (nullable = true)
#  |-- component_288: float (nullable = true)
#  |-- component_289: float (nullable = true)
#  |-- component_290: float (nullable = true)
#  |-- component_291: float (nullable = true)
#  |-- component_292: float (nullable = true)
#  |-- component_293: float (nullable = true)
#  |-- component_294: float (nullable = true)
#  |-- component_295: float (nullable = true)
#  |-- component_296: float (nullable = true)
#  |-- component_297: float (nullable = true)
#  |-- component_298: float (nullable = true)
#  |-- component_299: float (nullable = true)
#  |-- component_300: float (nullable = true)
#  |-- component_301: float (nullable = true)
#  |-- component_302: float (nullable = true)
#  |-- component_303: float (nullable = true)
#  |-- component_304: float (nullable = true)
#  |-- component_305: float (nullable = true)
#  |-- component_306: float (nullable = true)
#  |-- component_307: float (nullable = true)
#  |-- component_308: float (nullable = true)
#  |-- component_309: float (nullable = true)
#  |-- component_310: float (nullable = true)
#  |-- component_311: float (nullable = true)
#  |-- component_312: float (nullable = true)
#  |-- component_313: float (nullable = true)
#  |-- component_314: float (nullable = true)
#  |-- component_315: float (nullable = true)
#  |-- component_316: float (nullable = true)
#  |-- component_317: float (nullable = true)
#  |-- component_318: float (nullable = true)
#  |-- component_319: float (nullable = true)
#  |-- component_320: float (nullable = true)
#  |-- component_321: float (nullable = true)
#  |-- component_322: float (nullable = true)
#  |-- component_323: float (nullable = true)
#  |-- component_324: float (nullable = true)
#  |-- component_325: float (nullable = true)
#  |-- component_326: float (nullable = true)
#  |-- component_327: float (nullable = true)
#  |-- component_328: float (nullable = true)
#  |-- component_329: float (nullable = true)
#  |-- component_330: float (nullable = true)
#  |-- component_331: float (nullable = true)
#  |-- component_332: float (nullable = true)
#  |-- component_333: float (nullable = true)
#  |-- component_334: float (nullable = true)
#  |-- component_335: float (nullable = true)
#  |-- component_336: float (nullable = true)
#  |-- component_337: float (nullable = true)
#  |-- component_338: float (nullable = true)
#  |-- component_339: float (nullable = true)
#  |-- component_340: float (nullable = true)
#  |-- component_341: float (nullable = true)
#  |-- component_342: float (nullable = true)
#  |-- component_343: float (nullable = true)
#  |-- component_344: float (nullable = true)
#  |-- component_345: float (nullable = true)
#  |-- component_346: float (nullable = true)
#  |-- component_347: float (nullable = true)
#  |-- component_348: float (nullable = true)
#  |-- component_349: float (nullable = true)
#  |-- component_350: float (nullable = true)

# %%
# Colonne à enregistrer : 
selected_columns = ["path", "label"] + [f"component_{i+1}" for i in range(num_components)]
df_pca = df_pca.select(*selected_columns)

# %%
df_pca.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- label: string (nullable = true)
#  |-- component_1: float (nullable = true)
#  |-- component_2: float (nullable = true)
#  |-- component_3: float (nullable = true)
#  |-- component_4: float (nullable = true)
#  |-- component_5: float (nullable = true)
#  |-- component_6: float (nullable = true)
#  |-- component_7: float (nullable = true)
#  |-- component_8: float (nullable = true)
#  |-- component_9: float (nullable = true)
#  |-- component_10: float (nullable = true)
#  |-- component_11: float (nullable = true)
#  |-- component_12: float (nullable = true)
#  |-- component_13: float (nullable = true)
#  |-- component_14: float (nullable = true)
#  |-- component_15: float (nullable = true)
#  |-- component_16: float (nullable = true)
#  |-- component_17: float (nullable = true)
#  |-- component_18: float (nullable = true)
#  |-- component_19: float (nullable = true)
#  |-- component_20: float (nullable = true)
#  |-- component_21: float (nullable = true)
#  |-- component_22: float (nullable = true)
#  |-- component_23: float (nullable = true)
#  |-- component_24: float (nullable = true)
#  |-- component_25: float (nullable = true)
#  |-- component_26: float (nullable = true)
#  |-- component_27: float (nullable = true)
#  |-- component_28: float (nullable = true)
#  |-- component_29: float (nullable = true)
#  |-- component_30: float (nullable = true)
#  |-- component_31: float (nullable = true)
#  |-- component_32: float (nullable = true)
#  |-- component_33: float (nullable = true)
#  |-- component_34: float (nullable = true)
#  |-- component_35: float (nullable = true)
#  |-- component_36: float (nullable = true)
#  |-- component_37: float (nullable = true)
#  |-- component_38: float (nullable = true)
#  |-- component_39: float (nullable = true)
#  |-- component_40: float (nullable = true)
#  |-- component_41: float (nullable = true)
#  |-- component_42: float (nullable = true)
#  |-- component_43: float (nullable = true)
#  |-- component_44: float (nullable = true)
#  |-- component_45: float (nullable = true)
#  |-- component_46: float (nullable = true)
#  |-- component_47: float (nullable = true)
#  |-- component_48: float (nullable = true)
#  |-- component_49: float (nullable = true)
#  |-- component_50: float (nullable = true)
#  |-- component_51: float (nullable = true)
#  |-- component_52: float (nullable = true)
#  |-- component_53: float (nullable = true)
#  |-- component_54: float (nullable = true)
#  |-- component_55: float (nullable = true)
#  |-- component_56: float (nullable = true)
#  |-- component_57: float (nullable = true)
#  |-- component_58: float (nullable = true)
#  |-- component_59: float (nullable = true)
#  |-- component_60: float (nullable = true)
#  |-- component_61: float (nullable = true)
#  |-- component_62: float (nullable = true)
#  |-- component_63: float (nullable = true)
#  |-- component_64: float (nullable = true)
#  |-- component_65: float (nullable = true)
#  |-- component_66: float (nullable = true)
#  |-- component_67: float (nullable = true)
#  |-- component_68: float (nullable = true)
#  |-- component_69: float (nullable = true)
#  |-- component_70: float (nullable = true)
#  |-- component_71: float (nullable = true)
#  |-- component_72: float (nullable = true)
#  |-- component_73: float (nullable = true)
#  |-- component_74: float (nullable = true)
#  |-- component_75: float (nullable = true)
#  |-- component_76: float (nullable = true)
#  |-- component_77: float (nullable = true)
#  |-- component_78: float (nullable = true)
#  |-- component_79: float (nullable = true)
#  |-- component_80: float (nullable = true)
#  |-- component_81: float (nullable = true)
#  |-- component_82: float (nullable = true)
#  |-- component_83: float (nullable = true)
#  |-- component_84: float (nullable = true)
#  |-- component_85: float (nullable = true)
#  |-- component_86: float (nullable = true)
#  |-- component_87: float (nullable = true)
#  |-- component_88: float (nullable = true)
#  |-- component_89: float (nullable = true)
#  |-- component_90: float (nullable = true)
#  |-- component_91: float (nullable = true)
#  |-- component_92: float (nullable = true)
#  |-- component_93: float (nullable = true)
#  |-- component_94: float (nullable = true)
#  |-- component_95: float (nullable = true)
#  |-- component_96: float (nullable = true)
#  |-- component_97: float (nullable = true)
#  |-- component_98: float (nullable = true)
#  |-- component_99: float (nullable = true)
#  |-- component_100: float (nullable = true)
#  |-- component_101: float (nullable = true)
#  |-- component_102: float (nullable = true)
#  |-- component_103: float (nullable = true)
#  |-- component_104: float (nullable = true)
#  |-- component_105: float (nullable = true)
#  |-- component_106: float (nullable = true)
#  |-- component_107: float (nullable = true)
#  |-- component_108: float (nullable = true)
#  |-- component_109: float (nullable = true)
#  |-- component_110: float (nullable = true)
#  |-- component_111: float (nullable = true)
#  |-- component_112: float (nullable = true)
#  |-- component_113: float (nullable = true)
#  |-- component_114: float (nullable = true)
#  |-- component_115: float (nullable = true)
#  |-- component_116: float (nullable = true)
#  |-- component_117: float (nullable = true)
#  |-- component_118: float (nullable = true)
#  |-- component_119: float (nullable = true)
#  |-- component_120: float (nullable = true)
#  |-- component_121: float (nullable = true)
#  |-- component_122: float (nullable = true)
#  |-- component_123: float (nullable = true)
#  |-- component_124: float (nullable = true)
#  |-- component_125: float (nullable = true)
#  |-- component_126: float (nullable = true)
#  |-- component_127: float (nullable = true)
#  |-- component_128: float (nullable = true)
#  |-- component_129: float (nullable = true)
#  |-- component_130: float (nullable = true)
#  |-- component_131: float (nullable = true)
#  |-- component_132: float (nullable = true)
#  |-- component_133: float (nullable = true)
#  |-- component_134: float (nullable = true)
#  |-- component_135: float (nullable = true)
#  |-- component_136: float (nullable = true)
#  |-- component_137: float (nullable = true)
#  |-- component_138: float (nullable = true)
#  |-- component_139: float (nullable = true)
#  |-- component_140: float (nullable = true)
#  |-- component_141: float (nullable = true)
#  |-- component_142: float (nullable = true)
#  |-- component_143: float (nullable = true)
#  |-- component_144: float (nullable = true)
#  |-- component_145: float (nullable = true)
#  |-- component_146: float (nullable = true)
#  |-- component_147: float (nullable = true)
#  |-- component_148: float (nullable = true)
#  |-- component_149: float (nullable = true)
#  |-- component_150: float (nullable = true)
#  |-- component_151: float (nullable = true)
#  |-- component_152: float (nullable = true)
#  |-- component_153: float (nullable = true)
#  |-- component_154: float (nullable = true)
#  |-- component_155: float (nullable = true)
#  |-- component_156: float (nullable = true)
#  |-- component_157: float (nullable = true)
#  |-- component_158: float (nullable = true)
#  |-- component_159: float (nullable = true)
#  |-- component_160: float (nullable = true)
#  |-- component_161: float (nullable = true)
#  |-- component_162: float (nullable = true)
#  |-- component_163: float (nullable = true)
#  |-- component_164: float (nullable = true)
#  |-- component_165: float (nullable = true)
#  |-- component_166: float (nullable = true)
#  |-- component_167: float (nullable = true)
#  |-- component_168: float (nullable = true)
#  |-- component_169: float (nullable = true)
#  |-- component_170: float (nullable = true)
#  |-- component_171: float (nullable = true)
#  |-- component_172: float (nullable = true)
#  |-- component_173: float (nullable = true)
#  |-- component_174: float (nullable = true)
#  |-- component_175: float (nullable = true)
#  |-- component_176: float (nullable = true)
#  |-- component_177: float (nullable = true)
#  |-- component_178: float (nullable = true)
#  |-- component_179: float (nullable = true)
#  |-- component_180: float (nullable = true)
#  |-- component_181: float (nullable = true)
#  |-- component_182: float (nullable = true)
#  |-- component_183: float (nullable = true)
#  |-- component_184: float (nullable = true)
#  |-- component_185: float (nullable = true)
#  |-- component_186: float (nullable = true)
#  |-- component_187: float (nullable = true)
#  |-- component_188: float (nullable = true)
#  |-- component_189: float (nullable = true)
#  |-- component_190: float (nullable = true)
#  |-- component_191: float (nullable = true)
#  |-- component_192: float (nullable = true)
#  |-- component_193: float (nullable = true)
#  |-- component_194: float (nullable = true)
#  |-- component_195: float (nullable = true)
#  |-- component_196: float (nullable = true)
#  |-- component_197: float (nullable = true)
#  |-- component_198: float (nullable = true)
#  |-- component_199: float (nullable = true)
#  |-- component_200: float (nullable = true)
#  |-- component_201: float (nullable = true)
#  |-- component_202: float (nullable = true)
#  |-- component_203: float (nullable = true)
#  |-- component_204: float (nullable = true)
#  |-- component_205: float (nullable = true)
#  |-- component_206: float (nullable = true)
#  |-- component_207: float (nullable = true)
#  |-- component_208: float (nullable = true)
#  |-- component_209: float (nullable = true)
#  |-- component_210: float (nullable = true)
#  |-- component_211: float (nullable = true)
#  |-- component_212: float (nullable = true)
#  |-- component_213: float (nullable = true)
#  |-- component_214: float (nullable = true)
#  |-- component_215: float (nullable = true)
#  |-- component_216: float (nullable = true)
#  |-- component_217: float (nullable = true)
#  |-- component_218: float (nullable = true)
#  |-- component_219: float (nullable = true)
#  |-- component_220: float (nullable = true)
#  |-- component_221: float (nullable = true)
#  |-- component_222: float (nullable = true)
#  |-- component_223: float (nullable = true)
#  |-- component_224: float (nullable = true)
#  |-- component_225: float (nullable = true)
#  |-- component_226: float (nullable = true)
#  |-- component_227: float (nullable = true)
#  |-- component_228: float (nullable = true)
#  |-- component_229: float (nullable = true)
#  |-- component_230: float (nullable = true)
#  |-- component_231: float (nullable = true)
#  |-- component_232: float (nullable = true)
#  |-- component_233: float (nullable = true)
#  |-- component_234: float (nullable = true)
#  |-- component_235: float (nullable = true)
#  |-- component_236: float (nullable = true)
#  |-- component_237: float (nullable = true)
#  |-- component_238: float (nullable = true)
#  |-- component_239: float (nullable = true)
#  |-- component_240: float (nullable = true)
#  |-- component_241: float (nullable = true)
#  |-- component_242: float (nullable = true)
#  |-- component_243: float (nullable = true)
#  |-- component_244: float (nullable = true)
#  |-- component_245: float (nullable = true)
#  |-- component_246: float (nullable = true)
#  |-- component_247: float (nullable = true)
#  |-- component_248: float (nullable = true)
#  |-- component_249: float (nullable = true)
#  |-- component_250: float (nullable = true)
#  |-- component_251: float (nullable = true)
#  |-- component_252: float (nullable = true)
#  |-- component_253: float (nullable = true)
#  |-- component_254: float (nullable = true)
#  |-- component_255: float (nullable = true)
#  |-- component_256: float (nullable = true)
#  |-- component_257: float (nullable = true)
#  |-- component_258: float (nullable = true)
#  |-- component_259: float (nullable = true)
#  |-- component_260: float (nullable = true)
#  |-- component_261: float (nullable = true)
#  |-- component_262: float (nullable = true)
#  |-- component_263: float (nullable = true)
#  |-- component_264: float (nullable = true)
#  |-- component_265: float (nullable = true)
#  |-- component_266: float (nullable = true)
#  |-- component_267: float (nullable = true)
#  |-- component_268: float (nullable = true)
#  |-- component_269: float (nullable = true)
#  |-- component_270: float (nullable = true)
#  |-- component_271: float (nullable = true)
#  |-- component_272: float (nullable = true)
#  |-- component_273: float (nullable = true)
#  |-- component_274: float (nullable = true)
#  |-- component_275: float (nullable = true)
#  |-- component_276: float (nullable = true)
#  |-- component_277: float (nullable = true)
#  |-- component_278: float (nullable = true)
#  |-- component_279: float (nullable = true)
#  |-- component_280: float (nullable = true)
#  |-- component_281: float (nullable = true)
#  |-- component_282: float (nullable = true)
#  |-- component_283: float (nullable = true)
#  |-- component_284: float (nullable = true)
#  |-- component_285: float (nullable = true)
#  |-- component_286: float (nullable = true)
#  |-- component_287: float (nullable = true)
#  |-- component_288: float (nullable = true)
#  |-- component_289: float (nullable = true)
#  |-- component_290: float (nullable = true)
#  |-- component_291: float (nullable = true)
#  |-- component_292: float (nullable = true)
#  |-- component_293: float (nullable = true)
#  |-- component_294: float (nullable = true)
#  |-- component_295: float (nullable = true)
#  |-- component_296: float (nullable = true)
#  |-- component_297: float (nullable = true)
#  |-- component_298: float (nullable = true)
#  |-- component_299: float (nullable = true)
#  |-- component_300: float (nullable = true)
#  |-- component_301: float (nullable = true)
#  |-- component_302: float (nullable = true)
#  |-- component_303: float (nullable = true)
#  |-- component_304: float (nullable = true)
#  |-- component_305: float (nullable = true)
#  |-- component_306: float (nullable = true)
#  |-- component_307: float (nullable = true)
#  |-- component_308: float (nullable = true)
#  |-- component_309: float (nullable = true)
#  |-- component_310: float (nullable = true)
#  |-- component_311: float (nullable = true)
#  |-- component_312: float (nullable = true)
#  |-- component_313: float (nullable = true)
#  |-- component_314: float (nullable = true)
#  |-- component_315: float (nullable = true)
#  |-- component_316: float (nullable = true)
#  |-- component_317: float (nullable = true)
#  |-- component_318: float (nullable = true)
#  |-- component_319: float (nullable = true)
#  |-- component_320: float (nullable = true)
#  |-- component_321: float (nullable = true)
#  |-- component_322: float (nullable = true)
#  |-- component_323: float (nullable = true)
#  |-- component_324: float (nullable = true)
#  |-- component_325: float (nullable = true)
#  |-- component_326: float (nullable = true)
#  |-- component_327: float (nullable = true)
#  |-- component_328: float (nullable = true)
#  |-- component_329: float (nullable = true)
#  |-- component_330: float (nullable = true)
#  |-- component_331: float (nullable = true)
#  |-- component_332: float (nullable = true)
#  |-- component_333: float (nullable = true)
#  |-- component_334: float (nullable = true)
#  |-- component_335: float (nullable = true)
#  |-- component_336: float (nullable = true)
#  |-- component_337: float (nullable = true)
#  |-- component_338: float (nullable = true)
#  |-- component_339: float (nullable = true)
#  |-- component_340: float (nullable = true)
#  |-- component_341: float (nullable = true)
#  |-- component_342: float (nullable = true)
#  |-- component_343: float (nullable = true)
#  |-- component_344: float (nullable = true)
#  |-- component_345: float (nullable = true)
#  |-- component_346: float (nullable = true)
#  |-- component_347: float (nullable = true)
#  |-- component_348: float (nullable = true)
#  |-- component_349: float (nullable = true)
#  |-- component_350: float (nullable = true)

# %%
# Méthode 01
output_path = PATH_Result_csv + "/pca_csv_1"
df_pca.write.csv(output_path, header=True, mode="overwrite")

# %%
# Méthode 02
output_path = PATH_Result_csv + "/pca_csv_2"
df_pca.write.mode("overwrite").option("header","true").csv(output_path)

# %%
# Méthode 03
output_path = PATH_Result_csv + "/pca_csv_3"
df_pca.coalesce(1).write.csv(output_path, header=True, mode="overwrite")

# %%
# Importation 01
output_path = PATH_Result_csv + "/pca_csv_1"
Test_pca_1 = pd.read_csv(output_path + "/" + "file_name.csv")
Test_pca_1.shape
# Out:
# (451, 352)

# %%
# Importation 02
output_path = PATH_Result_csv + "/pca_csv_2"
Test_pca_2 = pd.read_csv(output_path + "/" + "file_name.csv")
Test_pca_2.shape
# Out:
# (451, 352)

# %%
# Importation 03
output_path = PATH_Result_csv + "/pca_csv_3"
Test_pca_3 = pd.read_csv(output_path + "/" + "file_name.csv")
Test_pca_3.shape
# Out:
# (451, 352)

# %%
Test_pca_3
# Out:
#                                                   path        label  \
# 0    file:/home/daipc/oc-projets/projetfruits/noteb...  apple_red_2
# 1    file:/home/daipc/oc-projets/projetfruits/noteb...       pear_1
# 2    file:/home/daipc/oc-projets/projetfruits/noteb...   zucchini_1
# 3    file:/home/daipc/oc-projets/projetfruits/noteb...   zucchini_1
# 4    file:/home/daipc/oc-projets/projetfruits/noteb...     carrot_1
# ..                                                 ...          ...
# 446  file:/home/daipc/oc-projets/projetfruits/noteb...  apple_red_2
# 447  file:/home/daipc/oc-projets/projetfruits/noteb...       pear_1
# 448  file:/home/daipc/oc-projets/projetfruits/noteb...  apple_red_2
# 449  file:/home/daipc/oc-projets/projetfruits/noteb...       pear_1
# 450  file:/home/daipc/oc-projets/projetfruits/noteb...       pear_1
#
#      component_1  component_2  component_3  component_4  component_5  \
# 0      -4.457928    -6.700167    -0.450851     1.713894    -2.330002
# 1      -6.936589    11.989290    -5.567602     8.594714    -3.599343
# 2       9.390083     5.995908     5.664782     6.812156    -1.462526
# 3       6.630799     6.284658     6.851362     6.547358    -0.693735
# 4      16.431297    -1.858502   -10.695012     6.315997    -3.137121
# ..           ...          ...          ...          ...          ...
# 446    -4.865873    -7.940898     1.004774     9.549164    -3.581604
# 447    -5.036658     4.622024    -2.007984    -0.107654    -6.804373
# 448    -1.090696    -4.355439    -0.504698    -3.186336    -0.039313
# 449    -6.393210    10.634883    -4.994072    12.427262     0.522687
# 450    -6.593993    10.853804    -2.769824     7.963721    -5.865558
#
#      component_6  component_7  component_8  ...  component_341  component_342  \
# 0       2.673411     3.115550    -1.292409  ...      -0.159494       0.175289
# 1      -1.505842     3.333837    -4.666601  ...      -0.265635       0.141402
# 2      -0.506818     3.569033     0.886619  ...      -0.148626       0.229828
# 3      -1.159967     1.619842    -0.251467  ...      -0.265741       0.314162
# 4       0.538829     3.244335     0.244492  ...      -0.179208       0.219398
# ..           ...          ...          ...  ...            ...            ...
# 446    -1.334430     3.662225    -0.459957  ...      -0.088795       0.102319
# 447    -4.180892     4.890408    -0.969034  ...      -0.119309       0.013146
# 448     6.573718     2.880600    -0.868170  ...      -0.065835       0.152010
# 449     1.759581     2.512892     2.129437  ...      -0.067878       0.237673
# 450    -1.475729     4.957253     0.817365  ...      -0.050773       0.136660
#
#      component_343  component_344  component_345  component_346  \
# 0         0.134298       0.157681       0.010945       0.288909
# 1         0.129588       0.328233       0.170131       0.332687
# 2         0.117160       0.330004       0.199985       0.246670
# 3         0.087772       0.329134       0.192901       0.204236
# 4         0.211376       0.286463       0.207592       0.172234
# ..             ...            ...            ...            ...
# 446      -0.007602       0.337858       0.213238       0.337695
# 447       0.191909       0.223400       0.249209       0.132571
# 448       0.128262       0.280048       0.151948       0.343342
# 449       0.072029       0.264939       0.219583       0.300271
# 450       0.233396       0.226508       0.253353       0.293337
#
#      component_347  component_348  component_349  component_350
# 0        -0.228167       0.339564      -0.185704      -0.318244
# 1        -0.335579       0.528246      -0.113957      -0.290963
# 2        -0.351446       0.399250      -0.124625      -0.296629
# 3        -0.255134       0.374595      -0.087262      -0.435572
# 4        -0.252858       0.388376      -0.095368      -0.311801
# ..             ...            ...            ...            ...
# 446      -0.204959       0.485822      -0.223121      -0.298649
# 447      -0.307575       0.415025      -0.103356      -0.420846
# 448      -0.395873       0.442403      -0.154784      -0.385237
# 449      -0.466307       0.458801      -0.118503      -0.321207
# 450      -0.393066       0.520346      -0.050462      -0.326739
#
# [451 rows x 352 columns]

# %%
type(Test_pca_3)
# Out:
# pandas.core.frame.DataFrame

# %%
Test_pca_3.columns
# Out:
# Index(['path', 'label', 'component_1', 'component_2', 'component_3',
#        'component_4', 'component_5', 'component_6', 'component_7',
#        'component_8',
#        ...
#        'component_341', 'component_342', 'component_343', 'component_344',
#        'component_345', 'component_346', 'component_347', 'component_348',
#        'component_349', 'component_350'],
#       dtype='object', length=352)
